# %% [markdown]
# # Importing Libraries

# %%
import requests
import json
import pandas as pd
from datetime import datetime

# %% [markdown]
# # GitHub API endpoint

# %%
# GitHub API endpoint
api_url = "https://api.github.com/search/repositories"

# %% [markdown]
# # Trending topics

# %%
# Trending topics
trending_topics = [
    "machine learning",
    "data visualization",
    "deep learning",
    "natural language processing",
    "data engineering",
    "data science",
    "python",
    "sql",
    "cloud computing",
    "big data"
]

# %% [markdown]
# # Function to fetch repository data

# %%
# Function to fetch repository data
def fetch_repository_data(topic):
    params = {
        "q": f"topic:{topic}",
        "sort": "stars",
        "per_page": 100
    }

    response = requests.get(api_url, params=params)
    data = response.json()["items"]

    repository_data = []
    for item in data:
        repository_data.append({
            "Topic":topic,
            "Repository_Name": item["name"],
            "Owner": item["owner"]["login"],
            "Description": item["description"],
            "URL": item["html_url"],
            "Programming_Language": item["language"],
            "Creation_Date": item["created_at"],
            "Last_Updated_Date": item["updated_at"],
            "Number_of_Stars": item["stargazers_count"],
            "Number_of_Forks": item["forks_count"],
            "Number_of_Open_Issues": item["open_issues_count"],
            "License_Type": item["license"]["name"] if item["license"] else "Unknown"
        })

    return repository_data

# %% [markdown]
# ## Breakdown of function

# %% [markdown]
# ## EX Topic

# %%
topic="machine learning"

# %% [markdown]
# ## Parameters to fetch data

# %%
#Parameters
params = {
    "q": f"topic:{topic}",
    "sort": "stars",
    "per_page": 50
}
params
# Out:
# {'q': 'topic:machine learning', 'sort': 'stars', 'per_page': 50}

# %% [markdown]
# ## Getting the response

# %%
response = requests.get(api_url, params=params)
data = response.json()["items"]

# %% [markdown]
# ## Fetched Data

# %%
data
# Out:
# [{'id': 87536046,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk4NzUzNjA0Ng==',
#   'name': 'mit-deep-learning-book-pdf',
#   'full_name': 'janishar/mit-deep-learning-book-pdf',
#   'private': False,
#   'owner': {'login': 'janishar',
#    'id': 11065002,
#    'node_id': 'MDQ6VXNlcjExMDY1MDAy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11065002?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/janishar',
#    'html_url': 'https://github.com/janishar',
#    'followers_url': 'https://api.github.com/users/janishar/followers',
#    'following_url': 'https://api.github.com/users/janishar/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/janishar/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/janishar/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/janishar/subscriptions',
#    'organizations_url': 'https://api.github.com/users/janishar/orgs',
#    'repos_url': 'https://api.github.com/users/janishar/repos',
#    'events_url': 'https://api.github.com/users/janishar/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/janishar/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/janishar/mit-deep-learning-book-pdf',
#   'description': 'MIT Deep Learning Book in PDF format (complete and parts) by Ian Goodfellow, Yoshua Bengio and Aaron Courville',
#   'fork': False,
#   'url': 'https://api.github.com/repos/janishar/mit-deep-learning-book-pdf',
#   'forks_url': 'https://api.github.com/repos/janishar/mit-deep-learning-book-pdf/forks',
#   'keys_url': 'https://api.github.com/repos/janishar/mit-deep-learning-book-pdf/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/janishar/mit-deep-learning-book-pdf/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/janishar/mit-deep-learning-book-pdf/teams',
#   'hooks_url': 'https://api.github.com/repos/janishar/mit-deep-learning-book-pdf/hooks',
#   'issue_events_url': 'https://api.github.com/repos/janishar/mit-deep-learning-book-pdf/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/janishar/mit-deep-learning-book-pdf/events',
#   'assignees_url': 'https://api.github.com/repos/janishar/mit-deep-learning-book-pdf/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/janishar/mit-deep-learning-book-pdf/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/janishar/mit-deep-learning-book-pdf/tags',
#   'blobs_url': 'https://api.github.com/repos/janishar/mit-deep-learning-book-pdf/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/janishar/mit-deep-learning-book-pdf/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/janishar/mit-deep-learning-book-pdf/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/janishar/mit-deep-learning-book-pdf/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/janishar/mit-deep-learning-book-pdf/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/janishar/mit-deep-learning-book-pdf/languages',
#   'stargazers_url': 'https://api.github.com/repos/janishar/mit-deep-learning-book-pdf/stargazers',
#   'contributors_url': 'https://api.github.com/repos/janishar/mit-deep-learning-book-pdf/contributors',
#   'subscribers_url': 'https://api.github.com/repos/janishar/mit-deep-learning-book-pdf/subscribers',
#   'subscription_url': 'https://api.github.com/repos/janishar/mit-deep-learning-book-pdf/subscription',
#   'commits_url': 'https://api.github.com/repos/janishar/mit-deep-learning-book-pdf/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/janishar/mit-deep-learning-book-pdf/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/janishar/mit-deep-learning-book-pdf/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/janishar/mit-deep-learning-book-pdf/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/janishar/mit-deep-learning-book-pdf/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/janishar/mit-deep-learning-book-pdf/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/janishar/mit-deep-learning-book-pdf/merges',
#   'archive_url': 'https://api.github.com/repos/janishar/mit-deep-learning-book-pdf/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/janishar/mit-deep-learning-book-pdf/downloads',
#   'issues_url': 'https://api.github.com/repos/janishar/mit-deep-learning-book-pdf/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/janishar/mit-deep-learning-book-pdf/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/janishar/mit-deep-learning-book-pdf/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/janishar/mit-deep-learning-book-pdf/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/janishar/mit-deep-learning-book-pdf/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/janishar/mit-deep-learning-book-pdf/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/janishar/mit-deep-learning-book-pdf/deployments',
#   'created_at': '2017-04-07T10:46:50Z',
#   'updated_at': '2024-10-06T04:30:47Z',
#   'pushed_at': '2023-10-09T08:55:12Z',
#   'git_url': 'git://github.com/janishar/mit-deep-learning-book-pdf.git',
#   'ssh_url': 'git@github.com:janishar/mit-deep-learning-book-pdf.git',
#   'clone_url': 'https://github.com/janishar/mit-deep-learning-book-pdf.git',
#   'svn_url': 'https://github.com/janishar/mit-deep-learning-book-pdf',
#   'homepage': None,
#   'size': 43571,
#   'stargazers_count': 12783,
#   'watchers_count': 12783,
#   'language': 'Java',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 2699,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 12,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': ['book',
#    'chapter',
#    'clear',
#    'deep-learning',
#    'deeplearning',
#    'excercises',
#    'good',
#    'learning',
#    'lecture-notes',
#    'linear-algebra',
#    'machine',
#    'machine-learning',
#    'mit',
#    'neural-network',
#    'neural-networks',
#    'pdf',
#    'print',
#    'printable',
#    'thinking'],
#   'visibility': 'public',
#   'forks': 2699,
#   'open_issues': 12,
#   'watchers': 12783,
#   'default_branch': 'master',
#   'score': 1.0},
#  {'id': 99881209,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk5OTg4MTIwOQ==',
#   'name': 'machine-learning-mindmap',
#   'full_name': 'dformoso/machine-learning-mindmap',
#   'private': False,
#   'owner': {'login': 'dformoso',
#    'id': 2955131,
#    'node_id': 'MDQ6VXNlcjI5NTUxMzE=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2955131?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dformoso',
#    'html_url': 'https://github.com/dformoso',
#    'followers_url': 'https://api.github.com/users/dformoso/followers',
#    'following_url': 'https://api.github.com/users/dformoso/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/dformoso/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/dformoso/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/dformoso/subscriptions',
#    'organizations_url': 'https://api.github.com/users/dformoso/orgs',
#    'repos_url': 'https://api.github.com/users/dformoso/repos',
#    'events_url': 'https://api.github.com/users/dformoso/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/dformoso/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/dformoso/machine-learning-mindmap',
#   'description': 'A mindmap summarising Machine Learning concepts, from Data Analysis to Deep Learning.',
#   'fork': False,
#   'url': 'https://api.github.com/repos/dformoso/machine-learning-mindmap',
#   'forks_url': 'https://api.github.com/repos/dformoso/machine-learning-mindmap/forks',
#   'keys_url': 'https://api.github.com/repos/dformoso/machine-learning-mindmap/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/dformoso/machine-learning-mindmap/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/dformoso/machine-learning-mindmap/teams',
#   'hooks_url': 'https://api.github.com/repos/dformoso/machine-learning-mindmap/hooks',
#   'issue_events_url': 'https://api.github.com/repos/dformoso/machine-learning-mindmap/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/dformoso/machine-learning-mindmap/events',
#   'assignees_url': 'https://api.github.com/repos/dformoso/machine-learning-mindmap/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/dformoso/machine-learning-mindmap/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/dformoso/machine-learning-mindmap/tags',
#   'blobs_url': 'https://api.github.com/repos/dformoso/machine-learning-mindmap/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/dformoso/machine-learning-mindmap/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/dformoso/machine-learning-mindmap/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/dformoso/machine-learning-mindmap/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/dformoso/machine-learning-mindmap/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/dformoso/machine-learning-mindmap/languages',
#   'stargazers_url': 'https://api.github.com/repos/dformoso/machine-learning-mindmap/stargazers',
#   'contributors_url': 'https://api.github.com/repos/dformoso/machine-learning-mindmap/contributors',
#   'subscribers_url': 'https://api.github.com/repos/dformoso/machine-learning-mindmap/subscribers',
#   'subscription_url': 'https://api.github.com/repos/dformoso/machine-learning-mindmap/subscription',
#   'commits_url': 'https://api.github.com/repos/dformoso/machine-learning-mindmap/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/dformoso/machine-learning-mindmap/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/dformoso/machine-learning-mindmap/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/dformoso/machine-learning-mindmap/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/dformoso/machine-learning-mindmap/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/dformoso/machine-learning-mindmap/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/dformoso/machine-learning-mindmap/merges',
#   'archive_url': 'https://api.github.com/repos/dformoso/machine-learning-mindmap/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/dformoso/machine-learning-mindmap/downloads',
#   'issues_url': 'https://api.github.com/repos/dformoso/machine-learning-mindmap/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/dformoso/machine-learning-mindmap/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/dformoso/machine-learning-mindmap/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/dformoso/machine-learning-mindmap/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/dformoso/machine-learning-mindmap/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/dformoso/machine-learning-mindmap/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/dformoso/machine-learning-mindmap/deployments',
#   'created_at': '2017-08-10T04:29:24Z',
#   'updated_at': '2024-10-05T15:14:52Z',
#   'pushed_at': '2020-05-30T07:34:20Z',
#   'git_url': 'git://github.com/dformoso/machine-learning-mindmap.git',
#   'ssh_url': 'git@github.com:dformoso/machine-learning-mindmap.git',
#   'clone_url': 'https://github.com/dformoso/machine-learning-mindmap.git',
#   'svn_url': 'https://github.com/dformoso/machine-learning-mindmap',
#   'homepage': None,
#   'size': 15538,
#   'stargazers_count': 6114,
#   'watchers_count': 6114,
#   'language': None,
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 1005,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 4,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': ['cheatsheet',
#    'data',
#    'jupyter',
#    'learning',
#    'machine',
#    'machine-learning',
#    'mindmap',
#    'python',
#    'science'],
#   'visibility': 'public',
#   'forks': 1005,
#   'open_issues': 4,
#   'watchers': 6114,
#   'default_branch': 'master',
#   'score': 1.0},
#  {'id': 72793197,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk3Mjc5MzE5Nw==',
#   'name': 'rapping-neural-network',
#   'full_name': 'robbiebarrat/rapping-neural-network',
#   'private': False,
#   'owner': {'login': 'robbiebarrat',
#    'id': 11282440,
#    'node_id': 'MDQ6VXNlcjExMjgyNDQw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11282440?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/robbiebarrat',
#    'html_url': 'https://github.com/robbiebarrat',
#    'followers_url': 'https://api.github.com/users/robbiebarrat/followers',
#    'following_url': 'https://api.github.com/users/robbiebarrat/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/robbiebarrat/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/robbiebarrat/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/robbiebarrat/subscriptions',
#    'organizations_url': 'https://api.github.com/users/robbiebarrat/orgs',
#    'repos_url': 'https://api.github.com/users/robbiebarrat/repos',
#    'events_url': 'https://api.github.com/users/robbiebarrat/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/robbiebarrat/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/robbiebarrat/rapping-neural-network',
#   'description': "Rap song writing recurrent neural network trained on Kanye West's entire discography",
#   'fork': False,
#   'url': 'https://api.github.com/repos/robbiebarrat/rapping-neural-network',
#   'forks_url': 'https://api.github.com/repos/robbiebarrat/rapping-neural-network/forks',
#   'keys_url': 'https://api.github.com/repos/robbiebarrat/rapping-neural-network/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/robbiebarrat/rapping-neural-network/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/robbiebarrat/rapping-neural-network/teams',
#   'hooks_url': 'https://api.github.com/repos/robbiebarrat/rapping-neural-network/hooks',
#   'issue_events_url': 'https://api.github.com/repos/robbiebarrat/rapping-neural-network/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/robbiebarrat/rapping-neural-network/events',
#   'assignees_url': 'https://api.github.com/repos/robbiebarrat/rapping-neural-network/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/robbiebarrat/rapping-neural-network/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/robbiebarrat/rapping-neural-network/tags',
#   'blobs_url': 'https://api.github.com/repos/robbiebarrat/rapping-neural-network/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/robbiebarrat/rapping-neural-network/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/robbiebarrat/rapping-neural-network/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/robbiebarrat/rapping-neural-network/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/robbiebarrat/rapping-neural-network/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/robbiebarrat/rapping-neural-network/languages',
#   'stargazers_url': 'https://api.github.com/repos/robbiebarrat/rapping-neural-network/stargazers',
#   'contributors_url': 'https://api.github.com/repos/robbiebarrat/rapping-neural-network/contributors',
#   'subscribers_url': 'https://api.github.com/repos/robbiebarrat/rapping-neural-network/subscribers',
#   'subscription_url': 'https://api.github.com/repos/robbiebarrat/rapping-neural-network/subscription',
#   'commits_url': 'https://api.github.com/repos/robbiebarrat/rapping-neural-network/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/robbiebarrat/rapping-neural-network/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/robbiebarrat/rapping-neural-network/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/robbiebarrat/rapping-neural-network/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/robbiebarrat/rapping-neural-network/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/robbiebarrat/rapping-neural-network/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/robbiebarrat/rapping-neural-network/merges',
#   'archive_url': 'https://api.github.com/repos/robbiebarrat/rapping-neural-network/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/robbiebarrat/rapping-neural-network/downloads',
#   'issues_url': 'https://api.github.com/repos/robbiebarrat/rapping-neural-network/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/robbiebarrat/rapping-neural-network/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/robbiebarrat/rapping-neural-network/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/robbiebarrat/rapping-neural-network/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/robbiebarrat/rapping-neural-network/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/robbiebarrat/rapping-neural-network/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/robbiebarrat/rapping-neural-network/deployments',
#   'created_at': '2016-11-03T22:39:49Z',
#   'updated_at': '2024-10-02T09:01:24Z',
#   'pushed_at': '2023-07-23T21:35:45Z',
#   'git_url': 'git://github.com/robbiebarrat/rapping-neural-network.git',
#   'ssh_url': 'git@github.com:robbiebarrat/rapping-neural-network.git',
#   'clone_url': 'https://github.com/robbiebarrat/rapping-neural-network.git',
#   'svn_url': 'https://github.com/robbiebarrat/rapping-neural-network',
#   'homepage': '',
#   'size': 18882,
#   'stargazers_count': 1043,
#   'watchers_count': 1043,
#   'language': 'Python',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 167,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 14,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': ['generative-art',
#    'learning',
#    'lyrics',
#    'machine',
#    'mp3',
#    'neural-network',
#    'rap',
#    'rap-songs',
#    'rhymes',
#    'songs',
#    'songwriting'],
#   'visibility': 'public',
#   'forks': 167,
#   'open_issues': 14,
#   'watchers': 1043,
#   'default_branch': 'master',
#   'score': 1.0},
#  {'id': 93950385,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk5Mzk1MDM4NQ==',
#   'name': 'awesome-machine-learning',
#   'full_name': 'onmyway133/awesome-machine-learning',
#   'private': False,
#   'owner': {'login': 'onmyway133',
#    'id': 2284279,
#    'node_id': 'MDQ6VXNlcjIyODQyNzk=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2284279?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/onmyway133',
#    'html_url': 'https://github.com/onmyway133',
#    'followers_url': 'https://api.github.com/users/onmyway133/followers',
#    'following_url': 'https://api.github.com/users/onmyway133/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/onmyway133/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/onmyway133/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/onmyway133/subscriptions',
#    'organizations_url': 'https://api.github.com/users/onmyway133/orgs',
#    'repos_url': 'https://api.github.com/users/onmyway133/repos',
#    'events_url': 'https://api.github.com/users/onmyway133/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/onmyway133/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/onmyway133/awesome-machine-learning',
#   'description': '🎰 A curated list of machine learning resources, preferably CoreML',
#   'fork': False,
#   'url': 'https://api.github.com/repos/onmyway133/awesome-machine-learning',
#   'forks_url': 'https://api.github.com/repos/onmyway133/awesome-machine-learning/forks',
#   'keys_url': 'https://api.github.com/repos/onmyway133/awesome-machine-learning/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/onmyway133/awesome-machine-learning/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/onmyway133/awesome-machine-learning/teams',
#   'hooks_url': 'https://api.github.com/repos/onmyway133/awesome-machine-learning/hooks',
#   'issue_events_url': 'https://api.github.com/repos/onmyway133/awesome-machine-learning/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/onmyway133/awesome-machine-learning/events',
#   'assignees_url': 'https://api.github.com/repos/onmyway133/awesome-machine-learning/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/onmyway133/awesome-machine-learning/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/onmyway133/awesome-machine-learning/tags',
#   'blobs_url': 'https://api.github.com/repos/onmyway133/awesome-machine-learning/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/onmyway133/awesome-machine-learning/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/onmyway133/awesome-machine-learning/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/onmyway133/awesome-machine-learning/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/onmyway133/awesome-machine-learning/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/onmyway133/awesome-machine-learning/languages',
#   'stargazers_url': 'https://api.github.com/repos/onmyway133/awesome-machine-learning/stargazers',
#   'contributors_url': 'https://api.github.com/repos/onmyway133/awesome-machine-learning/contributors',
#   'subscribers_url': 'https://api.github.com/repos/onmyway133/awesome-machine-learning/subscribers',
#   'subscription_url': 'https://api.github.com/repos/onmyway133/awesome-machine-learning/subscription',
#   'commits_url': 'https://api.github.com/repos/onmyway133/awesome-machine-learning/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/onmyway133/awesome-machine-learning/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/onmyway133/awesome-machine-learning/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/onmyway133/awesome-machine-learning/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/onmyway133/awesome-machine-learning/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/onmyway133/awesome-machine-learning/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/onmyway133/awesome-machine-learning/merges',
#   'archive_url': 'https://api.github.com/repos/onmyway133/awesome-machine-learning/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/onmyway133/awesome-machine-learning/downloads',
#   'issues_url': 'https://api.github.com/repos/onmyway133/awesome-machine-learning/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/onmyway133/awesome-machine-learning/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/onmyway133/awesome-machine-learning/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/onmyway133/awesome-machine-learning/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/onmyway133/awesome-machine-learning/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/onmyway133/awesome-machine-learning/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/onmyway133/awesome-machine-learning/deployments',
#   'created_at': '2017-06-10T16:05:45Z',
#   'updated_at': '2024-10-02T04:41:22Z',
#   'pushed_at': '2022-09-30T21:29:36Z',
#   'git_url': 'git://github.com/onmyway133/awesome-machine-learning.git',
#   'ssh_url': 'git@github.com:onmyway133/awesome-machine-learning.git',
#   'clone_url': 'https://github.com/onmyway133/awesome-machine-learning.git',
#   'svn_url': 'https://github.com/onmyway133/awesome-machine-learning',
#   'homepage': 'https://onmyway133.github.io/',
#   'size': 118,
#   'stargazers_count': 807,
#   'watchers_count': 807,
#   'language': None,
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 106,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 2,
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': ['ai',
#    'augmented',
#    'core-ml',
#    'language',
#    'learning',
#    'machine',
#    'model',
#    'processing',
#    'reality',
#    'vision'],
#   'visibility': 'public',
#   'forks': 106,
#   'open_issues': 2,
#   'watchers': 807,
#   'default_branch': 'master',
#   'score': 1.0},
#  {'id': 79006723,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk3OTAwNjcyMw==',
#   'name': 'DeepJ',
#   'full_name': 'calclavia/DeepJ',
#   'private': False,
#   'owner': {'login': 'calclavia',
#    'id': 1828968,
#    'node_id': 'MDQ6VXNlcjE4Mjg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1828968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/calclavia',
#    'html_url': 'https://github.com/calclavia',
#    'followers_url': 'https://api.github.com/users/calclavia/followers',
#    'following_url': 'https://api.github.com/users/calclavia/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/calclavia/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/calclavia/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/calclavia/subscriptions',
#    'organizations_url': 'https://api.github.com/users/calclavia/orgs',
#    'repos_url': 'https://api.github.com/users/calclavia/repos',
#    'events_url': 'https://api.github.com/users/calclavia/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/calclavia/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/calclavia/DeepJ',
#   'description': 'A deep learning model for style-specific music generation.',
#   'fork': False,
#   'url': 'https://api.github.com/repos/calclavia/DeepJ',
#   'forks_url': 'https://api.github.com/repos/calclavia/DeepJ/forks',
#   'keys_url': 'https://api.github.com/repos/calclavia/DeepJ/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/calclavia/DeepJ/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/calclavia/DeepJ/teams',
#   'hooks_url': 'https://api.github.com/repos/calclavia/DeepJ/hooks',
#   'issue_events_url': 'https://api.github.com/repos/calclavia/DeepJ/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/calclavia/DeepJ/events',
#   'assignees_url': 'https://api.github.com/repos/calclavia/DeepJ/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/calclavia/DeepJ/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/calclavia/DeepJ/tags',
#   'blobs_url': 'https://api.github.com/repos/calclavia/DeepJ/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/calclavia/DeepJ/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/calclavia/DeepJ/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/calclavia/DeepJ/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/calclavia/DeepJ/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/calclavia/DeepJ/languages',
#   'stargazers_url': 'https://api.github.com/repos/calclavia/DeepJ/stargazers',
#   'contributors_url': 'https://api.github.com/repos/calclavia/DeepJ/contributors',
#   'subscribers_url': 'https://api.github.com/repos/calclavia/DeepJ/subscribers',
#   'subscription_url': 'https://api.github.com/repos/calclavia/DeepJ/subscription',
#   'commits_url': 'https://api.github.com/repos/calclavia/DeepJ/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/calclavia/DeepJ/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/calclavia/DeepJ/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/calclavia/DeepJ/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/calclavia/DeepJ/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/calclavia/DeepJ/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/calclavia/DeepJ/merges',
#   'archive_url': 'https://api.github.com/repos/calclavia/DeepJ/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/calclavia/DeepJ/downloads',
#   'issues_url': 'https://api.github.com/repos/calclavia/DeepJ/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/calclavia/DeepJ/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/calclavia/DeepJ/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/calclavia/DeepJ/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/calclavia/DeepJ/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/calclavia/DeepJ/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/calclavia/DeepJ/deployments',
#   'created_at': '2017-01-15T06:43:17Z',
#   'updated_at': '2024-09-25T05:00:44Z',
#   'pushed_at': '2018-09-30T18:28:01Z',
#   'git_url': 'git://github.com/calclavia/DeepJ.git',
#   'ssh_url': 'git@github.com:calclavia/DeepJ.git',
#   'clone_url': 'https://github.com/calclavia/DeepJ.git',
#   'svn_url': 'https://github.com/calclavia/DeepJ',
#   'homepage': 'https://arxiv.org/abs/1801.00887',
#   'size': 660934,
#   'stargazers_count': 725,
#   'watchers_count': 725,
#   'language': 'Python',
#   'has_issues': True,
#   'has_projects': False,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 110,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 16,
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': ['composition',
#    'deep',
#    'generation',
#    'keras',
#    'learning',
#    'machine',
#    'music',
#    'tensorflow'],
#   'visibility': 'public',
#   'forks': 110,
#   'open_issues': 16,
#   'watchers': 725,
#   'default_branch': 'icsc',
#   'score': 1.0},
#  {'id': 203362007,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyMDMzNjIwMDc=',
#   'name': 'HungaBunga',
#   'full_name': 'ypeleg/HungaBunga',
#   'private': False,
#   'owner': {'login': 'ypeleg',
#    'id': 10883522,
#    'node_id': 'MDQ6VXNlcjEwODgzNTIy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10883522?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ypeleg',
#    'html_url': 'https://github.com/ypeleg',
#    'followers_url': 'https://api.github.com/users/ypeleg/followers',
#    'following_url': 'https://api.github.com/users/ypeleg/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ypeleg/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ypeleg/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ypeleg/subscriptions',
#    'organizations_url': 'https://api.github.com/users/ypeleg/orgs',
#    'repos_url': 'https://api.github.com/users/ypeleg/repos',
#    'events_url': 'https://api.github.com/users/ypeleg/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/ypeleg/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/ypeleg/HungaBunga',
#   'description': 'HungaBunga: Brute-Force all sklearn models with all parameters using .fit .predict!',
#   'fork': False,
#   'url': 'https://api.github.com/repos/ypeleg/HungaBunga',
#   'forks_url': 'https://api.github.com/repos/ypeleg/HungaBunga/forks',
#   'keys_url': 'https://api.github.com/repos/ypeleg/HungaBunga/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/ypeleg/HungaBunga/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/ypeleg/HungaBunga/teams',
#   'hooks_url': 'https://api.github.com/repos/ypeleg/HungaBunga/hooks',
#   'issue_events_url': 'https://api.github.com/repos/ypeleg/HungaBunga/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/ypeleg/HungaBunga/events',
#   'assignees_url': 'https://api.github.com/repos/ypeleg/HungaBunga/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/ypeleg/HungaBunga/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/ypeleg/HungaBunga/tags',
#   'blobs_url': 'https://api.github.com/repos/ypeleg/HungaBunga/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/ypeleg/HungaBunga/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/ypeleg/HungaBunga/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/ypeleg/HungaBunga/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/ypeleg/HungaBunga/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/ypeleg/HungaBunga/languages',
#   'stargazers_url': 'https://api.github.com/repos/ypeleg/HungaBunga/stargazers',
#   'contributors_url': 'https://api.github.com/repos/ypeleg/HungaBunga/contributors',
#   'subscribers_url': 'https://api.github.com/repos/ypeleg/HungaBunga/subscribers',
#   'subscription_url': 'https://api.github.com/repos/ypeleg/HungaBunga/subscription',
#   'commits_url': 'https://api.github.com/repos/ypeleg/HungaBunga/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/ypeleg/HungaBunga/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/ypeleg/HungaBunga/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/ypeleg/HungaBunga/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/ypeleg/HungaBunga/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/ypeleg/HungaBunga/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/ypeleg/HungaBunga/merges',
#   'archive_url': 'https://api.github.com/repos/ypeleg/HungaBunga/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/ypeleg/HungaBunga/downloads',
#   'issues_url': 'https://api.github.com/repos/ypeleg/HungaBunga/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/ypeleg/HungaBunga/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/ypeleg/HungaBunga/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/ypeleg/HungaBunga/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/ypeleg/HungaBunga/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/ypeleg/HungaBunga/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/ypeleg/HungaBunga/deployments',
#   'created_at': '2019-08-20T11:26:09Z',
#   'updated_at': '2024-09-11T03:23:32Z',
#   'pushed_at': '2020-08-02T17:23:15Z',
#   'git_url': 'git://github.com/ypeleg/HungaBunga.git',
#   'ssh_url': 'git@github.com:ypeleg/HungaBunga.git',
#   'clone_url': 'https://github.com/ypeleg/HungaBunga.git',
#   'svn_url': 'https://github.com/ypeleg/HungaBunga',
#   'homepage': '',
#   'size': 297,
#   'stargazers_count': 710,
#   'watchers_count': 710,
#   'language': 'Python',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 79,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 14,
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': ['automl',
#    'brute',
#    'fit',
#    'force',
#    'kaggle',
#    'learning',
#    'machine',
#    'predict',
#    'scikit-learn',
#    'sklearn'],
#   'visibility': 'public',
#   'forks': 79,
#   'open_issues': 14,
#   'watchers': 710,
#   'default_branch': 'master',
#   'score': 1.0},
#  {'id': 311069405,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzMTEwNjk0MDU=',
#   'name': 'practical-mlops-book',
#   'full_name': 'paiml/practical-mlops-book',
#   'private': False,
#   'owner': {'login': 'paiml',
#    'id': 23619593,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjIzNjE5NTkz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/23619593?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/paiml',
#    'html_url': 'https://github.com/paiml',
#    'followers_url': 'https://api.github.com/users/paiml/followers',
#    'following_url': 'https://api.github.com/users/paiml/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/paiml/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/paiml/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/paiml/subscriptions',
#    'organizations_url': 'https://api.github.com/users/paiml/orgs',
#    'repos_url': 'https://api.github.com/users/paiml/repos',
#    'events_url': 'https://api.github.com/users/paiml/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/paiml/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/paiml/practical-mlops-book',
#   'description': "[Book-2021] Practical MLOps O'Reilly Book",
#   'fork': False,
#   'url': 'https://api.github.com/repos/paiml/practical-mlops-book',
#   'forks_url': 'https://api.github.com/repos/paiml/practical-mlops-book/forks',
#   'keys_url': 'https://api.github.com/repos/paiml/practical-mlops-book/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/paiml/practical-mlops-book/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/paiml/practical-mlops-book/teams',
#   'hooks_url': 'https://api.github.com/repos/paiml/practical-mlops-book/hooks',
#   'issue_events_url': 'https://api.github.com/repos/paiml/practical-mlops-book/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/paiml/practical-mlops-book/events',
#   'assignees_url': 'https://api.github.com/repos/paiml/practical-mlops-book/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/paiml/practical-mlops-book/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/paiml/practical-mlops-book/tags',
#   'blobs_url': 'https://api.github.com/repos/paiml/practical-mlops-book/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/paiml/practical-mlops-book/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/paiml/practical-mlops-book/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/paiml/practical-mlops-book/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/paiml/practical-mlops-book/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/paiml/practical-mlops-book/languages',
#   'stargazers_url': 'https://api.github.com/repos/paiml/practical-mlops-book/stargazers',
#   'contributors_url': 'https://api.github.com/repos/paiml/practical-mlops-book/contributors',
#   'subscribers_url': 'https://api.github.com/repos/paiml/practical-mlops-book/subscribers',
#   'subscription_url': 'https://api.github.com/repos/paiml/practical-mlops-book/subscription',
#   'commits_url': 'https://api.github.com/repos/paiml/practical-mlops-book/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/paiml/practical-mlops-book/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/paiml/practical-mlops-book/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/paiml/practical-mlops-book/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/paiml/practical-mlops-book/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/paiml/practical-mlops-book/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/paiml/practical-mlops-book/merges',
#   'archive_url': 'https://api.github.com/repos/paiml/practical-mlops-book/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/paiml/practical-mlops-book/downloads',
#   'issues_url': 'https://api.github.com/repos/paiml/practical-mlops-book/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/paiml/practical-mlops-book/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/paiml/practical-mlops-book/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/paiml/practical-mlops-book/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/paiml/practical-mlops-book/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/paiml/practical-mlops-book/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/paiml/practical-mlops-book/deployments',
#   'created_at': '2020-11-08T13:30:47Z',
#   'updated_at': '2024-10-02T19:37:31Z',
#   'pushed_at': '2024-06-20T15:21:12Z',
#   'git_url': 'git://github.com/paiml/practical-mlops-book.git',
#   'ssh_url': 'git@github.com:paiml/practical-mlops-book.git',
#   'clone_url': 'https://github.com/paiml/practical-mlops-book.git',
#   'svn_url': 'https://github.com/paiml/practical-mlops-book',
#   'homepage': '',
#   'size': 4530,
#   'stargazers_count': 706,
#   'watchers_count': 706,
#   'language': 'Jupyter Notebook',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 284,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 2,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': ['cloud',
#    'learning',
#    'machine',
#    'machine-learning',
#    'oreilly-books',
#    'practical-mlops',
#    'python'],
#   'visibility': 'public',
#   'forks': 284,
#   'open_issues': 2,
#   'watchers': 706,
#   'default_branch': 'main',
#   'score': 1.0},
#  {'id': 100090407,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxMDAwOTA0MDc=',
#   'name': 'sklearn-classification',
#   'full_name': 'dformoso/sklearn-classification',
#   'private': False,
#   'owner': {'login': 'dformoso',
#    'id': 2955131,
#    'node_id': 'MDQ6VXNlcjI5NTUxMzE=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2955131?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dformoso',
#    'html_url': 'https://github.com/dformoso',
#    'followers_url': 'https://api.github.com/users/dformoso/followers',
#    'following_url': 'https://api.github.com/users/dformoso/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/dformoso/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/dformoso/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/dformoso/subscriptions',
#    'organizations_url': 'https://api.github.com/users/dformoso/orgs',
#    'repos_url': 'https://api.github.com/users/dformoso/repos',
#    'events_url': 'https://api.github.com/users/dformoso/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/dformoso/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/dformoso/sklearn-classification',
#   'description': 'Data Science Notebook on a Classification Task, using sklearn and Tensorflow.',
#   'fork': False,
#   'url': 'https://api.github.com/repos/dformoso/sklearn-classification',
#   'forks_url': 'https://api.github.com/repos/dformoso/sklearn-classification/forks',
#   'keys_url': 'https://api.github.com/repos/dformoso/sklearn-classification/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/dformoso/sklearn-classification/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/dformoso/sklearn-classification/teams',
#   'hooks_url': 'https://api.github.com/repos/dformoso/sklearn-classification/hooks',
#   'issue_events_url': 'https://api.github.com/repos/dformoso/sklearn-classification/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/dformoso/sklearn-classification/events',
#   'assignees_url': 'https://api.github.com/repos/dformoso/sklearn-classification/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/dformoso/sklearn-classification/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/dformoso/sklearn-classification/tags',
#   'blobs_url': 'https://api.github.com/repos/dformoso/sklearn-classification/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/dformoso/sklearn-classification/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/dformoso/sklearn-classification/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/dformoso/sklearn-classification/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/dformoso/sklearn-classification/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/dformoso/sklearn-classification/languages',
#   'stargazers_url': 'https://api.github.com/repos/dformoso/sklearn-classification/stargazers',
#   'contributors_url': 'https://api.github.com/repos/dformoso/sklearn-classification/contributors',
#   'subscribers_url': 'https://api.github.com/repos/dformoso/sklearn-classification/subscribers',
#   'subscription_url': 'https://api.github.com/repos/dformoso/sklearn-classification/subscription',
#   'commits_url': 'https://api.github.com/repos/dformoso/sklearn-classification/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/dformoso/sklearn-classification/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/dformoso/sklearn-classification/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/dformoso/sklearn-classification/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/dformoso/sklearn-classification/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/dformoso/sklearn-classification/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/dformoso/sklearn-classification/merges',
#   'archive_url': 'https://api.github.com/repos/dformoso/sklearn-classification/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/dformoso/sklearn-classification/downloads',
#   'issues_url': 'https://api.github.com/repos/dformoso/sklearn-classification/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/dformoso/sklearn-classification/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/dformoso/sklearn-classification/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/dformoso/sklearn-classification/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/dformoso/sklearn-classification/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/dformoso/sklearn-classification/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/dformoso/sklearn-classification/deployments',
#   'created_at': '2017-08-12T05:05:33Z',
#   'updated_at': '2024-10-05T04:34:20Z',
#   'pushed_at': '2021-12-21T05:36:30Z',
#   'git_url': 'git://github.com/dformoso/sklearn-classification.git',
#   'ssh_url': 'git@github.com:dformoso/sklearn-classification.git',
#   'clone_url': 'https://github.com/dformoso/sklearn-classification.git',
#   'svn_url': 'https://github.com/dformoso/sklearn-classification',
#   'homepage': '',
#   'size': 11328,
#   'stargazers_count': 690,
#   'watchers_count': 690,
# ...
#   'subscription_url': 'https://api.github.com/repos/Projects-Developer/Google-Stock-Price-Prediction-by-Deep-Learning/subscription',
#   'commits_url': 'https://api.github.com/repos/Projects-Developer/Google-Stock-Price-Prediction-by-Deep-Learning/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Projects-Developer/Google-Stock-Price-Prediction-by-Deep-Learning/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Projects-Developer/Google-Stock-Price-Prediction-by-Deep-Learning/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Projects-Developer/Google-Stock-Price-Prediction-by-Deep-Learning/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Projects-Developer/Google-Stock-Price-Prediction-by-Deep-Learning/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Projects-Developer/Google-Stock-Price-Prediction-by-Deep-Learning/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Projects-Developer/Google-Stock-Price-Prediction-by-Deep-Learning/merges',
#   'archive_url': 'https://api.github.com/repos/Projects-Developer/Google-Stock-Price-Prediction-by-Deep-Learning/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Projects-Developer/Google-Stock-Price-Prediction-by-Deep-Learning/downloads',
#   'issues_url': 'https://api.github.com/repos/Projects-Developer/Google-Stock-Price-Prediction-by-Deep-Learning/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Projects-Developer/Google-Stock-Price-Prediction-by-Deep-Learning/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Projects-Developer/Google-Stock-Price-Prediction-by-Deep-Learning/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Projects-Developer/Google-Stock-Price-Prediction-by-Deep-Learning/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Projects-Developer/Google-Stock-Price-Prediction-by-Deep-Learning/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Projects-Developer/Google-Stock-Price-Prediction-by-Deep-Learning/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Projects-Developer/Google-Stock-Price-Prediction-by-Deep-Learning/deployments',
#   'created_at': '2021-05-11T12:21:07Z',
#   'updated_at': '2024-08-23T09:37:40Z',
#   'pushed_at': '2021-12-20T19:53:47Z',
#   'git_url': 'git://github.com/Projects-Developer/Google-Stock-Price-Prediction-by-Deep-Learning.git',
#   'ssh_url': 'git@github.com:Projects-Developer/Google-Stock-Price-Prediction-by-Deep-Learning.git',
#   'clone_url': 'https://github.com/Projects-Developer/Google-Stock-Price-Prediction-by-Deep-Learning.git',
#   'svn_url': 'https://github.com/Projects-Developer/Google-Stock-Price-Prediction-by-Deep-Learning',
#   'homepage': 'https://www.cse-projects.com/',
#   'size': 543,
#   'stargazers_count': 38,
#   'watchers_count': 38,
#   'language': 'Jupyter Notebook',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 4,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': ['btech-project',
#    'btechfinalyear',
#    'capstone-project',
#    'data-science',
#    'deep-learning',
#    'deep-neural-networks',
#    'final-year-project',
#    'google-projects',
#    'ieee',
#    'lstm',
#    'machine',
#    'machine-learning',
#    'major-project',
#    'minor-projects',
#    'prediction-model',
#    'semester-project',
#    'stock-price-prediction',
#    'stocks'],
#   'visibility': 'public',
#   'forks': 4,
#   'open_issues': 0,
#   'watchers': 38,
#   'default_branch': 'main',
#   'score': 1.0},
#  {'id': 78777688,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk3ODc3NzY4OA==',
#   'name': 'Neural-Tile',
#   'full_name': 'ProGamerGov/Neural-Tile',
#   'private': False,
#   'owner': {'login': 'ProGamerGov',
#    'id': 10626398,
#    'node_id': 'MDQ6VXNlcjEwNjI2Mzk4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10626398?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ProGamerGov',
#    'html_url': 'https://github.com/ProGamerGov',
#    'followers_url': 'https://api.github.com/users/ProGamerGov/followers',
#    'following_url': 'https://api.github.com/users/ProGamerGov/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ProGamerGov/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ProGamerGov/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ProGamerGov/subscriptions',
#    'organizations_url': 'https://api.github.com/users/ProGamerGov/orgs',
#    'repos_url': 'https://api.github.com/users/ProGamerGov/repos',
#    'events_url': 'https://api.github.com/users/ProGamerGov/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/ProGamerGov/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/ProGamerGov/Neural-Tile',
#   'description': 'A better tiling script for Neural-Style',
#   'fork': False,
#   'url': 'https://api.github.com/repos/ProGamerGov/Neural-Tile',
#   'forks_url': 'https://api.github.com/repos/ProGamerGov/Neural-Tile/forks',
#   'keys_url': 'https://api.github.com/repos/ProGamerGov/Neural-Tile/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/ProGamerGov/Neural-Tile/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/ProGamerGov/Neural-Tile/teams',
#   'hooks_url': 'https://api.github.com/repos/ProGamerGov/Neural-Tile/hooks',
#   'issue_events_url': 'https://api.github.com/repos/ProGamerGov/Neural-Tile/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/ProGamerGov/Neural-Tile/events',
#   'assignees_url': 'https://api.github.com/repos/ProGamerGov/Neural-Tile/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/ProGamerGov/Neural-Tile/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/ProGamerGov/Neural-Tile/tags',
#   'blobs_url': 'https://api.github.com/repos/ProGamerGov/Neural-Tile/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/ProGamerGov/Neural-Tile/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/ProGamerGov/Neural-Tile/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/ProGamerGov/Neural-Tile/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/ProGamerGov/Neural-Tile/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/ProGamerGov/Neural-Tile/languages',
#   'stargazers_url': 'https://api.github.com/repos/ProGamerGov/Neural-Tile/stargazers',
#   'contributors_url': 'https://api.github.com/repos/ProGamerGov/Neural-Tile/contributors',
#   'subscribers_url': 'https://api.github.com/repos/ProGamerGov/Neural-Tile/subscribers',
#   'subscription_url': 'https://api.github.com/repos/ProGamerGov/Neural-Tile/subscription',
#   'commits_url': 'https://api.github.com/repos/ProGamerGov/Neural-Tile/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/ProGamerGov/Neural-Tile/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/ProGamerGov/Neural-Tile/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/ProGamerGov/Neural-Tile/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/ProGamerGov/Neural-Tile/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/ProGamerGov/Neural-Tile/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/ProGamerGov/Neural-Tile/merges',
#   'archive_url': 'https://api.github.com/repos/ProGamerGov/Neural-Tile/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/ProGamerGov/Neural-Tile/downloads',
#   'issues_url': 'https://api.github.com/repos/ProGamerGov/Neural-Tile/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/ProGamerGov/Neural-Tile/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/ProGamerGov/Neural-Tile/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/ProGamerGov/Neural-Tile/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/ProGamerGov/Neural-Tile/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/ProGamerGov/Neural-Tile/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/ProGamerGov/Neural-Tile/deployments',
#   'created_at': '2017-01-12T19:07:56Z',
#   'updated_at': '2024-08-12T19:27:07Z',
#   'pushed_at': '2017-02-10T02:42:07Z',
#   'git_url': 'git://github.com/ProGamerGov/Neural-Tile.git',
#   'ssh_url': 'git@github.com:ProGamerGov/Neural-Tile.git',
#   'clone_url': 'https://github.com/ProGamerGov/Neural-Tile.git',
#   'svn_url': 'https://github.com/ProGamerGov/Neural-Tile',
#   'homepage': None,
#   'size': 41,
#   'stargazers_count': 36,
#   'watchers_count': 36,
#   'language': 'Shell',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 8,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 2,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': ['artificial-intelligence',
#    'artistic',
#    'artwork',
#    'deep-learning',
#    'drift',
#    'imagemagick',
#    'learning',
#    'machine',
#    'multires',
#    'network',
#    'neural',
#    'neural-network',
#    'neural-style',
#    'style',
#    'style-scale',
#    'style-transfer',
#    'tile',
#    'tiling-scripts',
#    'transfer'],
#   'visibility': 'public',
#   'forks': 8,
#   'open_issues': 2,
#   'watchers': 36,
#   'default_branch': 'master',
#   'score': 1.0},
#  {'id': 760944063,
#   'node_id': 'R_kgDOLVsVvw',
#   'name': 'nuclease_design',
#   'full_name': 'google-deepmind/nuclease_design',
#   'private': False,
#   'owner': {'login': 'google-deepmind',
#    'id': 8596759,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTY3NTk=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8596759?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/google-deepmind',
#    'html_url': 'https://github.com/google-deepmind',
#    'followers_url': 'https://api.github.com/users/google-deepmind/followers',
#    'following_url': 'https://api.github.com/users/google-deepmind/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/google-deepmind/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/google-deepmind/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/google-deepmind/subscriptions',
#    'organizations_url': 'https://api.github.com/users/google-deepmind/orgs',
#    'repos_url': 'https://api.github.com/users/google-deepmind/repos',
#    'events_url': 'https://api.github.com/users/google-deepmind/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/google-deepmind/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/google-deepmind/nuclease_design',
#   'description': 'ML-guided enzyme engineering',
#   'fork': False,
#   'url': 'https://api.github.com/repos/google-deepmind/nuclease_design',
#   'forks_url': 'https://api.github.com/repos/google-deepmind/nuclease_design/forks',
#   'keys_url': 'https://api.github.com/repos/google-deepmind/nuclease_design/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/google-deepmind/nuclease_design/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/google-deepmind/nuclease_design/teams',
#   'hooks_url': 'https://api.github.com/repos/google-deepmind/nuclease_design/hooks',
#   'issue_events_url': 'https://api.github.com/repos/google-deepmind/nuclease_design/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/google-deepmind/nuclease_design/events',
#   'assignees_url': 'https://api.github.com/repos/google-deepmind/nuclease_design/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/google-deepmind/nuclease_design/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/google-deepmind/nuclease_design/tags',
#   'blobs_url': 'https://api.github.com/repos/google-deepmind/nuclease_design/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/google-deepmind/nuclease_design/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/google-deepmind/nuclease_design/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/google-deepmind/nuclease_design/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/google-deepmind/nuclease_design/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/google-deepmind/nuclease_design/languages',
#   'stargazers_url': 'https://api.github.com/repos/google-deepmind/nuclease_design/stargazers',
#   'contributors_url': 'https://api.github.com/repos/google-deepmind/nuclease_design/contributors',
#   'subscribers_url': 'https://api.github.com/repos/google-deepmind/nuclease_design/subscribers',
#   'subscription_url': 'https://api.github.com/repos/google-deepmind/nuclease_design/subscription',
#   'commits_url': 'https://api.github.com/repos/google-deepmind/nuclease_design/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/google-deepmind/nuclease_design/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/google-deepmind/nuclease_design/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/google-deepmind/nuclease_design/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/google-deepmind/nuclease_design/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/google-deepmind/nuclease_design/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/google-deepmind/nuclease_design/merges',
#   'archive_url': 'https://api.github.com/repos/google-deepmind/nuclease_design/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/google-deepmind/nuclease_design/downloads',
#   'issues_url': 'https://api.github.com/repos/google-deepmind/nuclease_design/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/google-deepmind/nuclease_design/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/google-deepmind/nuclease_design/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/google-deepmind/nuclease_design/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/google-deepmind/nuclease_design/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/google-deepmind/nuclease_design/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/google-deepmind/nuclease_design/deployments',
#   'created_at': '2024-02-21T00:14:12Z',
#   'updated_at': '2024-09-18T08:21:35Z',
#   'pushed_at': '2024-09-11T16:38:09Z',
#   'git_url': 'git://github.com/google-deepmind/nuclease_design.git',
#   'ssh_url': 'git@github.com:google-deepmind/nuclease_design.git',
#   'clone_url': 'https://github.com/google-deepmind/nuclease_design.git',
#   'svn_url': 'https://github.com/google-deepmind/nuclease_design',
#   'homepage': '',
#   'size': 34760,
#   'stargazers_count': 35,
#   'watchers_count': 35,
#   'language': 'Jupyter Notebook',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 11,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': ['engineering', 'learning', 'machine', 'protein'],
#   'visibility': 'public',
#   'forks': 11,
#   'open_issues': 0,
#   'watchers': 35,
#   'default_branch': 'main',
#   'score': 1.0}]

# %% [markdown]
# ## Data Extraction

# %%
repository_data = []
for item in data:
    repository_data.append({
        "Topic":topic,
        "Repository_Name": item["name"],
        "Owner": item["owner"]["login"],
        "Description": item["description"],
        "URL": item["html_url"],
        "Programming_Language": item["language"],
        "Creation_Date": item["created_at"],
        "Last_Updated_Date": item["updated_at"],
        "Number_of_Stars": item["stargazers_count"],
        "Number_of_Forks": item["forks_count"],
        "Number_of_Open_Issues": item["open_issues_count"],
        "License_Type": item["license"]["name"] if item["license"] else "Unknown"
    })

# %%
repository_data
# Out:
# [{'Topic': 'machine learning',
#   'Repository_Name': 'mit-deep-learning-book-pdf',
#   'Owner': 'janishar',
#   'Description': 'MIT Deep Learning Book in PDF format (complete and parts) by Ian Goodfellow, Yoshua Bengio and Aaron Courville',
#   'URL': 'https://github.com/janishar/mit-deep-learning-book-pdf',
#   'Programming_Language': 'Java',
#   'Creation_Date': '2017-04-07T10:46:50Z',
#   'Last_Updated_Date': '2024-10-06T04:30:47Z',
#   'Number_of_Stars': 12783,
#   'Number_of_Forks': 2699,
#   'Number_of_Open_Issues': 12,
#   'License_Type': 'Unknown'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'machine-learning-mindmap',
#   'Owner': 'dformoso',
#   'Description': 'A mindmap summarising Machine Learning concepts, from Data Analysis to Deep Learning.',
#   'URL': 'https://github.com/dformoso/machine-learning-mindmap',
#   'Programming_Language': None,
#   'Creation_Date': '2017-08-10T04:29:24Z',
#   'Last_Updated_Date': '2024-10-05T15:14:52Z',
#   'Number_of_Stars': 6114,
#   'Number_of_Forks': 1005,
#   'Number_of_Open_Issues': 4,
#   'License_Type': 'Apache License 2.0'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'rapping-neural-network',
#   'Owner': 'robbiebarrat',
#   'Description': "Rap song writing recurrent neural network trained on Kanye West's entire discography",
#   'URL': 'https://github.com/robbiebarrat/rapping-neural-network',
#   'Programming_Language': 'Python',
#   'Creation_Date': '2016-11-03T22:39:49Z',
#   'Last_Updated_Date': '2024-10-02T09:01:24Z',
#   'Number_of_Stars': 1043,
#   'Number_of_Forks': 167,
#   'Number_of_Open_Issues': 14,
#   'License_Type': 'Unknown'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'awesome-machine-learning',
#   'Owner': 'onmyway133',
#   'Description': '🎰 A curated list of machine learning resources, preferably CoreML',
#   'URL': 'https://github.com/onmyway133/awesome-machine-learning',
#   'Programming_Language': None,
#   'Creation_Date': '2017-06-10T16:05:45Z',
#   'Last_Updated_Date': '2024-10-02T04:41:22Z',
#   'Number_of_Stars': 807,
#   'Number_of_Forks': 106,
#   'Number_of_Open_Issues': 2,
#   'License_Type': 'MIT License'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'DeepJ',
#   'Owner': 'calclavia',
#   'Description': 'A deep learning model for style-specific music generation.',
#   'URL': 'https://github.com/calclavia/DeepJ',
#   'Programming_Language': 'Python',
#   'Creation_Date': '2017-01-15T06:43:17Z',
#   'Last_Updated_Date': '2024-09-25T05:00:44Z',
#   'Number_of_Stars': 725,
#   'Number_of_Forks': 110,
#   'Number_of_Open_Issues': 16,
#   'License_Type': 'MIT License'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'HungaBunga',
#   'Owner': 'ypeleg',
#   'Description': 'HungaBunga: Brute-Force all sklearn models with all parameters using .fit .predict!',
#   'URL': 'https://github.com/ypeleg/HungaBunga',
#   'Programming_Language': 'Python',
#   'Creation_Date': '2019-08-20T11:26:09Z',
#   'Last_Updated_Date': '2024-09-11T03:23:32Z',
#   'Number_of_Stars': 710,
#   'Number_of_Forks': 79,
#   'Number_of_Open_Issues': 14,
#   'License_Type': 'MIT License'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'practical-mlops-book',
#   'Owner': 'paiml',
#   'Description': "[Book-2021] Practical MLOps O'Reilly Book",
#   'URL': 'https://github.com/paiml/practical-mlops-book',
#   'Programming_Language': 'Jupyter Notebook',
#   'Creation_Date': '2020-11-08T13:30:47Z',
#   'Last_Updated_Date': '2024-10-02T19:37:31Z',
#   'Number_of_Stars': 706,
#   'Number_of_Forks': 284,
#   'Number_of_Open_Issues': 2,
#   'License_Type': 'Unknown'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'sklearn-classification',
#   'Owner': 'dformoso',
#   'Description': 'Data Science Notebook on a Classification Task, using sklearn and Tensorflow.',
#   'URL': 'https://github.com/dformoso/sklearn-classification',
#   'Programming_Language': 'Jupyter Notebook',
#   'Creation_Date': '2017-08-12T05:05:33Z',
#   'Last_Updated_Date': '2024-10-05T04:34:20Z',
#   'Number_of_Stars': 690,
#   'Number_of_Forks': 232,
#   'Number_of_Open_Issues': 7,
#   'License_Type': 'GNU General Public License v3.0'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'neptune-client',
#   'Owner': 'neptune-ai',
#   'Description': '📘 The experiment tracker for foundation model training',
#   'URL': 'https://github.com/neptune-ai/neptune-client',
#   'Programming_Language': 'Python',
#   'Creation_Date': '2019-02-11T11:25:57Z',
#   'Last_Updated_Date': '2024-10-05T12:04:01Z',
#   'Number_of_Stars': 576,
#   'Number_of_Forks': 63,
#   'Number_of_Open_Issues': 30,
#   'License_Type': 'Apache License 2.0'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'moviebox',
#   'Owner': 'klaudiosinani',
#   'Description': 'Machine learning movie recommending system',
#   'URL': 'https://github.com/klaudiosinani/moviebox',
#   'Programming_Language': 'Python',
#   'Creation_Date': '2018-01-23T20:37:19Z',
#   'Last_Updated_Date': '2024-09-23T14:20:54Z',
#   'Number_of_Stars': 524,
#   'Number_of_Forks': 55,
#   'Number_of_Open_Issues': 4,
#   'License_Type': 'MIT License'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'SharpLearning',
#   'Owner': 'mdabros',
#   'Description': 'Machine learning for C# .Net  ',
#   'URL': 'https://github.com/mdabros/SharpLearning',
#   'Programming_Language': 'C#',
#   'Creation_Date': '2017-02-14T19:46:39Z',
#   'Last_Updated_Date': '2024-09-16T17:54:48Z',
#   'Number_of_Stars': 383,
#   'Number_of_Forks': 84,
#   'Number_of_Open_Issues': 51,
#   'License_Type': 'MIT License'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'opml',
#   'Owner': 'ora-io',
#   'Description': 'OPML: OPtimistic Machine Learning on Blockchain',
#   'URL': 'https://github.com/ora-io/opml',
#   'Programming_Language': 'Solidity',
#   'Creation_Date': '2023-07-07T03:35:39Z',
#   'Last_Updated_Date': '2024-09-30T04:16:49Z',
#   'Number_of_Stars': 338,
#   'Number_of_Forks': 76,
#   'Number_of_Open_Issues': 3,
#   'License_Type': 'MIT License'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'modelStudio',
#   'Owner': 'ModelOriented',
#   'Description': '📍 Interactive Studio for Explanatory Model Analysis',
#   'URL': 'https://github.com/ModelOriented/modelStudio',
#   'Programming_Language': 'R',
#   'Creation_Date': '2019-07-10T07:59:07Z',
#   'Last_Updated_Date': '2024-10-03T09:17:40Z',
#   'Number_of_Stars': 324,
#   'Number_of_Forks': 32,
#   'Number_of_Open_Issues': 4,
#   'License_Type': 'GNU General Public License v3.0'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'DeepSort',
#   'Owner': 'CorentinB',
#   'Description': '🧠 AI powered image tagger backed by DeepDetect',
#   'URL': 'https://github.com/CorentinB/DeepSort',
#   'Programming_Language': 'Go',
#   'Creation_Date': '2018-08-18T04:06:21Z',
#   'Last_Updated_Date': '2024-08-17T20:23:50Z',
#   'Number_of_Stars': 241,
#   'Number_of_Forks': 15,
#   'Number_of_Open_Issues': 2,
#   'License_Type': 'GNU General Public License v3.0'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'mrcl',
#   'Owner': 'khurramjaved96',
#   'Description': 'Code for the NeurIPS19 paper "Meta-Learning Representations for Continual Learning"',
#   'URL': 'https://github.com/khurramjaved96/mrcl',
#   'Programming_Language': 'Python',
#   'Creation_Date': '2019-05-27T18:36:29Z',
#   'Last_Updated_Date': '2024-09-21T22:55:13Z',
#   'Number_of_Stars': 194,
#   'Number_of_Forks': 26,
#   'Number_of_Open_Issues': 6,
#   'License_Type': 'Unknown'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'Retro-Learning-Environment',
#   'Owner': 'nadavbh12',
#   'Description': 'The Retro Learning Environment (RLE) -- a learning framework for AI',
#   'URL': 'https://github.com/nadavbh12/Retro-Learning-Environment',
#   'Programming_Language': 'C++',
#   'Creation_Date': '2015-11-11T10:26:28Z',
#   'Last_Updated_Date': '2024-09-25T00:00:28Z',
#   'Number_of_Stars': 184,
#   'Number_of_Forks': 40,
#   'Number_of_Open_Issues': 5,
#   'License_Type': 'Other'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'Makine-Ogrenmesi',
#   'Owner': 'SerayBeser',
#   'Description': 'Makine Öğrenmesi Türkçe Kaynak',
#   'URL': 'https://github.com/SerayBeser/Makine-Ogrenmesi',
#   'Programming_Language': 'Python',
#   'Creation_Date': '2017-11-01T12:04:54Z',
#   'Last_Updated_Date': '2024-08-15T08:52:22Z',
#   'Number_of_Stars': 142,
#   'Number_of_Forks': 28,
#   'Number_of_Open_Issues': 1,
#   'License_Type': 'MIT License'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'scenescoop',
#   'Owner': 'cvalenzuela',
#   'Description': 'A tool to describe the content of videos and suggest similar scenes in other videos/films.',
#   'URL': 'https://github.com/cvalenzuela/scenescoop',
#   'Programming_Language': 'Python',
#   'Creation_Date': '2017-12-05T03:43:15Z',
#   'Last_Updated_Date': '2024-09-02T20:06:27Z',
#   'Number_of_Stars': 135,
#   'Number_of_Forks': 21,
#   'Number_of_Open_Issues': 5,
#   'License_Type': 'Unknown'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'practical-ml-for-cybersecurity',
#   'Owner': 'shramos',
#   'Description': 'More than twenty practical cases with real datasets of application of Machine Learning to the field of Cybersecurity',
#   'URL': 'https://github.com/shramos/practical-ml-for-cybersecurity',
#   'Programming_Language': 'Jupyter Notebook',
#   'Creation_Date': '2020-04-18T08:25:04Z',
#   'Last_Updated_Date': '2024-10-02T13:05:14Z',
#   'Number_of_Stars': 131,
#   'Number_of_Forks': 81,
#   'Number_of_Open_Issues': 1,
#   'License_Type': 'Unknown'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'Sigma',
#   'Owner': 'ThinkingTransistor',
#   'Description': 'Rocket powered machine learning. Create, compare, adapt, improve - artificial intelligence at the speed of thought.',
#   'URL': 'https://github.com/ThinkingTransistor/Sigma',
#   'Programming_Language': 'C#',
#   'Creation_Date': '2016-10-29T12:52:48Z',
#   'Last_Updated_Date': '2024-02-04T08:14:54Z',
#   'Number_of_Stars': 121,
#   'Number_of_Forks': 13,
#   'Number_of_Open_Issues': 4,
#   'License_Type': 'Other'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'Predictive_Maintenance_using_Machine-Learning_Microsoft_Casestudy',
#   'Owner': 'ashishpatel26',
#   'Description': 'Predictive_Maintenance_using_Machine-Learning_Microsoft_Casestudy',
#   'URL': 'https://github.com/ashishpatel26/Predictive_Maintenance_using_Machine-Learning_Microsoft_Casestudy',
#   'Programming_Language': 'Jupyter Notebook',
#   'Creation_Date': '2018-04-05T10:15:35Z',
#   'Last_Updated_Date': '2024-09-18T07:53:47Z',
#   'Number_of_Stars': 118,
#   'Number_of_Forks': 86,
#   'Number_of_Open_Issues': 3,
#   'License_Type': 'Unknown'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'mlearn',
#   'Owner': 'materialsvirtuallab',
#   'Description': 'Benchmark Suite for Machine Learning Interatomic Potentials for Materials',
#   'URL': 'https://github.com/materialsvirtuallab/mlearn',
#   'Programming_Language': 'Python',
#   'Creation_Date': '2019-04-25T16:05:49Z',
#   'Last_Updated_Date': '2024-06-12T14:01:48Z',
#   'Number_of_Stars': 105,
#   'Number_of_Forks': 27,
#   'Number_of_Open_Issues': 1,
#   'License_Type': 'BSD 3-Clause "New" or "Revised" License'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'MALWARE-DETECTION-FINAL-YEAR-PROJECT',
#   'Owner': 'Vatshayan',
#   'Description': 'Final Year Malware Detection Project with PPT, Research Paper, code and Synopsis. Malware detection project by Machine Learning ALgorithms.',
#   'URL': 'https://github.com/Vatshayan/MALWARE-DETECTION-FINAL-YEAR-PROJECT',
#   'Programming_Language': 'Jupyter Notebook',
#   'Creation_Date': '2021-03-21T18:41:34Z',
#   'Last_Updated_Date': '2024-10-05T20:47:54Z',
#   'Number_of_Stars': 99,
#   'Number_of_Forks': 11,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'Unknown'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'surv_ai',
#   'Owner': 'DanielBalsam',
#   'Description': 'A framework to empower forecasting using Large Language Models (LLMs)',
#   'URL': 'https://github.com/DanielBalsam/surv_ai',
#   'Programming_Language': 'Python',
#   'Creation_Date': '2023-04-16T19:26:26Z',
#   'Last_Updated_Date': '2024-10-02T11:28:41Z',
#   'Number_of_Stars': 99,
#   'Number_of_Forks': 3,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'MIT License'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'iOS11-VisionFrameWork',
#   'Owner': 'gunapandianraj',
#   'Description': 'Vision Framework IOS WWDC 2017',
#   'URL': 'https://github.com/gunapandianraj/iOS11-VisionFrameWork',
#   'Programming_Language': 'Swift',
#   'Creation_Date': '2017-06-25T15:49:25Z',
#   'Last_Updated_Date': '2024-09-15T11:28:04Z',
#   'Number_of_Stars': 96,
#   'Number_of_Forks': 13,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'MIT License'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'computer-vision-ND',
#   'Owner': 'Bjarten',
#   'Description': 'Projects and exercises for the Udacity Computer Vision Nanodegree',
#   'URL': 'https://github.com/Bjarten/computer-vision-ND',
#   'Programming_Language': 'Jupyter Notebook',
#   'Creation_Date': '2018-10-04T05:11:31Z',
#   'Last_Updated_Date': '2024-08-09T20:04:36Z',
#   'Number_of_Stars': 93,
#   'Number_of_Forks': 45,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'Unknown'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'survshap',
#   'Owner': 'MI2DataLab',
#   'Description': 'SurvSHAP(t): Time-dependent explanations of machine learning survival models',
#   'URL': 'https://github.com/MI2DataLab/survshap',
#   'Programming_Language': 'Jupyter Notebook',
#   'Creation_Date': '2022-08-03T08:36:27Z',
#   'Last_Updated_Date': '2024-09-25T21:37:34Z',
#   'Number_of_Stars': 79,
#   'Number_of_Forks': 15,
#   'Number_of_Open_Issues': 9,
#   'License_Type': 'MIT License'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'Deep-LearningAI',
#   'Owner': 'GSimas',
#   'Description': '🇦🇮 Deep Learning AI course on Coursera (Andrew Ng)',
#   'URL': 'https://github.com/GSimas/Deep-LearningAI',
#   'Programming_Language': 'Jupyter Notebook',
#   'Creation_Date': '2017-08-29T15:48:01Z',
#   'Last_Updated_Date': '2024-08-28T15:11:28Z',
#   'Number_of_Stars': 71,
#   'Number_of_Forks': 57,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'MIT License'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'machine_learning_examples',
#   'Owner': 'nithyadurai87',
#   'Description': 'machine_learning_examples',
#   'URL': 'https://github.com/nithyadurai87/machine_learning_examples',
#   'Programming_Language': 'HTML',
#   'Creation_Date': '2018-11-10T06:04:16Z',
#   'Last_Updated_Date': '2024-09-01T11:13:01Z',
#   'Number_of_Stars': 69,
#   'Number_of_Forks': 49,
#   'Number_of_Open_Issues': 1,
#   'License_Type': 'Unknown'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'GPT2-Telegram-Chatbot',
#   'Owner': 'xluxeq',
#   'Description': 'GPT-2 Telegram Chat bot',
#   'URL': 'https://github.com/xluxeq/GPT2-Telegram-Chatbot',
#   'Programming_Language': 'Python',
#   'Creation_Date': '2019-09-30T20:23:00Z',
#   'Last_Updated_Date': '2023-12-28T09:03:24Z',
#   'Number_of_Stars': 69,
#   'Number_of_Forks': 17,
#   'Number_of_Open_Issues': 1,
#   'License_Type': 'Unknown'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'MSDS696-Masters-Final-Project',
#   'Owner': 'Vettejeep',
#   'Description': 'Earthquake Prediction Challenge with LightGBM and XGBoost',
#   'URL': 'https://github.com/Vettejeep/MSDS696-Masters-Final-Project',
#   'Programming_Language': 'Jupyter Notebook',
#   'Creation_Date': '2019-04-30T16:19:26Z',
#   'Last_Updated_Date': '2024-07-01T12:15:50Z',
#   'Number_of_Stars': 66,
#   'Number_of_Forks': 28,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'Apache License 2.0'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'dance2dance',
#   'Owner': 'pkmital',
#   'Description': 'Discrete Figures AI: Seq2Seq of Dance Data (Mikiko + Daito Manabe + Kyle McDonald)',
#   'URL': 'https://github.com/pkmital/dance2dance',
#   'Programming_Language': 'Python',
#   'Creation_Date': '2018-03-31T00:24:20Z',
#   'Last_Updated_Date': '2024-09-23T04:04:10Z',
#   'Number_of_Stars': 60,
#   'Number_of_Forks': 10,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'Apache License 2.0'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'reinforcement-learning-resources',
#   'Owner': 'datascienceid',
#   'Description': 'A curated list of awesome reinforcement courses, video lectures, books, library and many more. ',
#   'URL': 'https://github.com/datascienceid/reinforcement-learning-resources',
#   'Programming_Language': None,
#   'Creation_Date': '2018-04-14T03:25:00Z',
#   'Last_Updated_Date': '2024-08-24T14:37:42Z',
#   'Number_of_Stars': 59,
#   'Number_of_Forks': 29,
#   'Number_of_Open_Issues': 1,
#   'License_Type': 'Unknown'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'matcalc',
#   'Owner': 'materialsvirtuallab',
#   'Description': 'A python library for calculating materials properties from the PES',
#   'URL': 'https://github.com/materialsvirtuallab/matcalc',
#   'Programming_Language': 'Python',
#   'Creation_Date': '2023-07-25T02:04:04Z',
#   'Last_Updated_Date': '2024-10-03T22:30:24Z',
#   'Number_of_Stars': 58,
#   'Number_of_Forks': 10,
#   'Number_of_Open_Issues': 3,
#   'License_Type': 'BSD 3-Clause "New" or "Revised" License'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'TensorFI',
#   'Owner': 'DependableSystemsLab',
#   'Description': 'TensorFI is a fault injection framework for injecting both hardware and software faults into applications written using the TensorFlow framework. You can find more information about TensorFI in the paper below.',
#   'URL': 'https://github.com/DependableSystemsLab/TensorFI',
#   'Programming_Language': 'Python',
#   'Creation_Date': '2018-08-28T04:56:18Z',
#   'Last_Updated_Date': '2024-09-04T23:55:29Z',
#   'Number_of_Stars': 52,
#   'Number_of_Forks': 23,
#   'Number_of_Open_Issues': 14,
#   'License_Type': 'MIT License'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'GPT3-Telegram-Chatbot',
#   'Owner': 'xluxeq',
#   'Description': 'OpenAI chatbot for Telegram using GPT-3.',
#   'URL': 'https://github.com/xluxeq/GPT3-Telegram-Chatbot',
#   'Programming_Language': 'Python',
#   'Creation_Date': '2021-05-28T15:34:33Z',
#   'Last_Updated_Date': '2024-08-12T20:13:25Z',
#   'Number_of_Stars': 52,
#   'Number_of_Forks': 34,
#   'Number_of_Open_Issues': 2,
#   'License_Type': 'Unknown'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'wearable_stress_classification',
#   'Owner': 'chriotte',
#   'Description': 'Stress classifier with AutoML',
#   'URL': 'https://github.com/chriotte/wearable_stress_classification',
#   'Programming_Language': 'HTML',
#   'Creation_Date': '2018-07-03T19:30:46Z',
#   'Last_Updated_Date': '2024-06-13T04:53:40Z',
#   'Number_of_Stars': 52,
#   'Number_of_Forks': 35,
#   'Number_of_Open_Issues': 3,
#   'License_Type': 'Unknown'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'Protect-Images-from-AI-PixelGuard',
#   'Owner': 'captainzero93',
#   'Description': 'PixelGuard protects images from AI scraping and unauthorized use in AI training, such as facial recognition models or style transfer algorithms. It employs multiple invisible protection techniques that mostly imperceptible to the eye but can interfere with AI processing.',
#   'URL': 'https://github.com/captainzero93/Protect-Images-from-AI-PixelGuard',
#   'Programming_Language': 'Python',
#   'Creation_Date': '2024-08-10T22:11:01Z',
#   'Last_Updated_Date': '2024-09-29T19:51:28Z',
#   'Number_of_Stars': 51,
#   'Number_of_Forks': 4,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'Other'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'landmap',
#   'Owner': 'Envirometrix',
#   'Description': 'Landmap package for R',
#   'URL': 'https://github.com/Envirometrix/landmap',
#   'Programming_Language': 'R',
#   'Creation_Date': '2019-05-24T20:11:10Z',
#   'Last_Updated_Date': '2024-08-08T04:39:17Z',
#   'Number_of_Stars': 46,
#   'Number_of_Forks': 13,
#   'Number_of_Open_Issues': 6,
#   'License_Type': 'Unknown'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'CryptoInscriber',
#   'Owner': 'Optixal',
#   'Description': ':chart_with_upwards_trend: A live cryptocurrency historical trade data blotter. Download live historical trade data from any cryptoexchange, be it for machine learning, backtesting/visualizing trading strategies or for Quantopian/Zipline.',
#   'URL': 'https://github.com/Optixal/CryptoInscriber',
#   'Programming_Language': 'Python',
#   'Creation_Date': '2017-11-12T16:52:19Z',
#   'Last_Updated_Date': '2024-08-12T04:04:40Z',
#   'Number_of_Stars': 45,
#   'Number_of_Forks': 4,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'MIT License'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'edge-computer-vision',
#   'Owner': 'noahgift',
#   'Description': 'Edge Computer Vision Course',
#   'URL': 'https://github.com/noahgift/edge-computer-vision',
#   'Programming_Language': 'Jupyter Notebook',
#   'Creation_Date': '2019-12-13T17:13:12Z',
#   'Last_Updated_Date': '2024-07-12T07:33:11Z',
#   'Number_of_Stars': 44,
#   'Number_of_Forks': 18,
#   'Number_of_Open_Issues': 3,
#   'License_Type': 'Other'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'Tensorflow-Image-Classification',
#   'Owner': 'AxelAli',
#   'Description': 'Easy/Updated Tensorflow Image Classification',
#   'URL': 'https://github.com/AxelAli/Tensorflow-Image-Classification',
#   'Programming_Language': 'Python',
#   'Creation_Date': '2017-02-18T05:08:08Z',
#   'Last_Updated_Date': '2023-09-06T11:28:57Z',
#   'Number_of_Stars': 42,
#   'Number_of_Forks': 14,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'Unknown'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'Machine-Learning',
#   'Owner': 'aydinnyunus',
#   'Description': 'Machine Learning (Easy to Hard step by step)',
#   'URL': 'https://github.com/aydinnyunus/Machine-Learning',
#   'Programming_Language': 'Jupyter Notebook',
#   'Creation_Date': '2019-11-27T16:05:19Z',
#   'Last_Updated_Date': '2024-08-17T14:53:47Z',
#   'Number_of_Stars': 41,
#   'Number_of_Forks': 8,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'Unknown'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'distracted-driver-detection',
#   'Owner': 'luisarojas',
#   'Description': 'Predicting the likelihood of what the driver is doing in each of the pictures in the dataset.',
#   'URL': 'https://github.com/luisarojas/distracted-driver-detection',
#   'Programming_Language': 'Jupyter Notebook',
#   'Creation_Date': '2017-10-17T17:06:12Z',
#   'Last_Updated_Date': '2024-03-27T07:58:31Z',
#   'Number_of_Stars': 41,
#   'Number_of_Forks': 20,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'MIT License'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'rsgislib-tutorials',
#   'Owner': 'remotesensinginfo',
#   'Description': 'A set of notebook tutorials for RSGISLib.',
#   'URL': 'https://github.com/remotesensinginfo/rsgislib-tutorials',
#   'Programming_Language': 'Jupyter Notebook',
#   'Creation_Date': '2022-01-23T21:40:18Z',
#   'Last_Updated_Date': '2024-09-19T07:17:29Z',
#   'Number_of_Stars': 41,
#   'Number_of_Forks': 4,
#   'Number_of_Open_Issues': 3,
#   'License_Type': 'MIT License'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'net_intrusion_detection',
#   'Owner': 'Jumabek',
#   'Description': 'Network intrusion detection with Machine Learning (Deep Learning) experiment : 1d-cnn, softmax, neural networks, convolution',
#   'URL': 'https://github.com/Jumabek/net_intrusion_detection',
#   'Programming_Language': 'Jupyter Notebook',
#   'Creation_Date': '2019-11-19T02:35:11Z',
#   'Last_Updated_Date': '2024-09-25T13:21:34Z',
#   'Number_of_Stars': 40,
#   'Number_of_Forks': 14,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'Unknown'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'lobe',
#   'Owner': 'davidawad',
#   'Description': "Lobe is the world's first AI paralegal. ",
#   'URL': 'https://github.com/davidawad/lobe',
#   'Programming_Language': 'Python',
#   'Creation_Date': '2018-03-02T20:13:23Z',
#   'Last_Updated_Date': '2024-10-03T14:47:31Z',
#   'Number_of_Stars': 40,
#   'Number_of_Forks': 10,
#   'Number_of_Open_Issues': 18,
#   'License_Type': 'Unknown'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'Google-Stock-Price-Prediction-by-Deep-Learning',
#   'Owner': 'Projects-Developer',
#   'Description': 'Top Class Stock Price Prediction Project through Machine Learning Algorithms for Google. Easy Understanding and Implementation. B.tech Final Year College Project. ',
#   'URL': 'https://github.com/Projects-Developer/Google-Stock-Price-Prediction-by-Deep-Learning',
#   'Programming_Language': 'Jupyter Notebook',
#   'Creation_Date': '2021-05-11T12:21:07Z',
#   'Last_Updated_Date': '2024-08-23T09:37:40Z',
#   'Number_of_Stars': 38,
#   'Number_of_Forks': 4,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'Unknown'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'Neural-Tile',
#   'Owner': 'ProGamerGov',
#   'Description': 'A better tiling script for Neural-Style',
#   'URL': 'https://github.com/ProGamerGov/Neural-Tile',
#   'Programming_Language': 'Shell',
#   'Creation_Date': '2017-01-12T19:07:56Z',
#   'Last_Updated_Date': '2024-08-12T19:27:07Z',
#   'Number_of_Stars': 36,
#   'Number_of_Forks': 8,
#   'Number_of_Open_Issues': 2,
#   'License_Type': 'Unknown'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'nuclease_design',
#   'Owner': 'google-deepmind',
#   'Description': 'ML-guided enzyme engineering',
#   'URL': 'https://github.com/google-deepmind/nuclease_design',
#   'Programming_Language': 'Jupyter Notebook',
#   'Creation_Date': '2024-02-21T00:14:12Z',
#   'Last_Updated_Date': '2024-09-18T08:21:35Z',
#   'Number_of_Stars': 35,
#   'Number_of_Forks': 11,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'Apache License 2.0'}]

# %% [markdown]
# ## DataFrame Conversion

# %%
repo_df = pd.DataFrame(repository_data)
repo_df
# Out:
#                Topic                                    Repository_Name  \
# 0   machine learning                         mit-deep-learning-book-pdf
# 1   machine learning                           machine-learning-mindmap
# 2   machine learning                             rapping-neural-network
# 3   machine learning                           awesome-machine-learning
# 4   machine learning                                              DeepJ
# 5   machine learning                                         HungaBunga
# 6   machine learning                               practical-mlops-book
# 7   machine learning                             sklearn-classification
# 8   machine learning                                     neptune-client
# 9   machine learning                                           moviebox
# 10  machine learning                                      SharpLearning
# 11  machine learning                                               opml
# 12  machine learning                                        modelStudio
# 13  machine learning                                           DeepSort
# 14  machine learning                                               mrcl
# 15  machine learning                         Retro-Learning-Environment
# 16  machine learning                                   Makine-Ogrenmesi
# 17  machine learning                                         scenescoop
# 18  machine learning                     practical-ml-for-cybersecurity
# 19  machine learning                                              Sigma
# 20  machine learning  Predictive_Maintenance_using_Machine-Learning_...
# 21  machine learning                                             mlearn
# 22  machine learning               MALWARE-DETECTION-FINAL-YEAR-PROJECT
# 23  machine learning                                            surv_ai
# 24  machine learning                              iOS11-VisionFrameWork
# 25  machine learning                                 computer-vision-ND
# 26  machine learning                                           survshap
# 27  machine learning                                    Deep-LearningAI
# 28  machine learning                          machine_learning_examples
# 29  machine learning                              GPT2-Telegram-Chatbot
# 30  machine learning                      MSDS696-Masters-Final-Project
# 31  machine learning                                        dance2dance
# 32  machine learning                   reinforcement-learning-resources
# 33  machine learning                                            matcalc
# 34  machine learning                                           TensorFI
# 35  machine learning                              GPT3-Telegram-Chatbot
# 36  machine learning                     wearable_stress_classification
# 37  machine learning                  Protect-Images-from-AI-PixelGuard
# 38  machine learning                                            landmap
# 39  machine learning                                    CryptoInscriber
# 40  machine learning                               edge-computer-vision
# 41  machine learning                    Tensorflow-Image-Classification
# 42  machine learning                                   Machine-Learning
# 43  machine learning                        distracted-driver-detection
# 44  machine learning                                 rsgislib-tutorials
# 45  machine learning                            net_intrusion_detection
# 46  machine learning                                               lobe
# 47  machine learning     Google-Stock-Price-Prediction-by-Deep-Learning
# 48  machine learning                                        Neural-Tile
# 49  machine learning                                    nuclease_design
#
#                    Owner                                        Description  \
# 0               janishar  MIT Deep Learning Book in PDF format (complete...
# 1               dformoso  A mindmap summarising Machine Learning concept...
# 2           robbiebarrat  Rap song writing recurrent neural network trai...
# 3             onmyway133  🎰 A curated list of machine learning resources...
# 4              calclavia  A deep learning model for style-specific music...
# 5                 ypeleg  HungaBunga: Brute-Force all sklearn models wit...
# 6                  paiml          [Book-2021] Practical MLOps O'Reilly Book
# 7               dformoso  Data Science Notebook on a Classification Task...
# 8             neptune-ai  📘 The experiment tracker for foundation model ...
# 9          klaudiosinani         Machine learning movie recommending system
# 10               mdabros                     Machine learning for C# .Net
# 11                ora-io    OPML: OPtimistic Machine Learning on Blockchain
# 12         ModelOriented  📍 Interactive Studio for Explanatory Model Ana...
# 13             CorentinB     🧠 AI powered image tagger backed by DeepDetect
# 14        khurramjaved96  Code for the NeurIPS19 paper "Meta-Learning Re...
# 15             nadavbh12  The Retro Learning Environment (RLE) -- a lear...
# 16            SerayBeser                     Makine Öğrenmesi Türkçe Kaynak
# 17           cvalenzuela  A tool to describe the content of videos and s...
# 18               shramos  More than twenty practical cases with real dat...
# 19    ThinkingTransistor  Rocket powered machine learning. Create, compa...
# 20         ashishpatel26  Predictive_Maintenance_using_Machine-Learning_...
# 21   materialsvirtuallab  Benchmark Suite for Machine Learning Interatom...
# 22             Vatshayan  Final Year Malware Detection Project with PPT,...
# 23          DanielBalsam  A framework to empower forecasting using Large...
# 24        gunapandianraj                     Vision Framework IOS WWDC 2017
# 25               Bjarten  Projects and exercises for the Udacity Compute...
# 26            MI2DataLab  SurvSHAP(t): Time-dependent explanations of ma...
# 27                GSimas  🇦🇮 Deep Learning AI course on Coursera (Andrew...
# 28         nithyadurai87                          machine_learning_examples
# 29                xluxeq                            GPT-2 Telegram Chat bot
# 30             Vettejeep  Earthquake Prediction Challenge with LightGBM ...
# 31               pkmital  Discrete Figures AI: Seq2Seq of Dance Data (Mi...
# 32         datascienceid  A curated list of awesome reinforcement course...
# 33   materialsvirtuallab  A python library for calculating materials pro...
# 34  DependableSystemsLab  TensorFI is a fault injection framework for in...
# 35                xluxeq           OpenAI chatbot for Telegram using GPT-3.
# 36              chriotte                      Stress classifier with AutoML
# 37         captainzero93  PixelGuard protects images from AI scraping an...
# 38          Envirometrix                              Landmap package for R
# 39               Optixal  :chart_with_upwards_trend: A live cryptocurren...
# 40              noahgift                        Edge Computer Vision Course
# 41               AxelAli       Easy/Updated Tensorflow Image Classification
# 42           aydinnyunus       Machine Learning (Easy to Hard step by step)
# 43            luisarojas  Predicting the likelihood of what the driver i...
# 44     remotesensinginfo          A set of notebook tutorials for RSGISLib.
# 45               Jumabek  Network intrusion detection with Machine Learn...
# 46             davidawad           Lobe is the world's first AI paralegal.
# 47    Projects-Developer  Top Class Stock Price Prediction Project throu...
# 48           ProGamerGov            A better tiling script for Neural-Style
# 49       google-deepmind                       ML-guided enzyme engineering
#
#                                                   URL Programming_Language  \
# 0   https://github.com/janishar/mit-deep-learning-...                 Java
# 1   https://github.com/dformoso/machine-learning-m...                 None
# 2   https://github.com/robbiebarrat/rapping-neural...               Python
# 3   https://github.com/onmyway133/awesome-machine-...                 None
# 4                  https://github.com/calclavia/DeepJ               Python
# 5                https://github.com/ypeleg/HungaBunga               Python
# 6       https://github.com/paiml/practical-mlops-book     Jupyter Notebook
# 7   https://github.com/dformoso/sklearn-classifica...     Jupyter Notebook
# 8        https://github.com/neptune-ai/neptune-client               Python
# 9           https://github.com/klaudiosinani/moviebox               Python
# 10           https://github.com/mdabros/SharpLearning                   C#
# 11                     https://github.com/ora-io/opml             Solidity
# 12       https://github.com/ModelOriented/modelStudio                    R
# 13              https://github.com/CorentinB/DeepSort                   Go
# 14             https://github.com/khurramjaved96/mrcl               Python
# 15  https://github.com/nadavbh12/Retro-Learning-En...                  C++
# 16     https://github.com/SerayBeser/Makine-Ogrenmesi               Python
# 17          https://github.com/cvalenzuela/scenescoop               Python
# 18  https://github.com/shramos/practical-ml-for-cy...     Jupyter Notebook
# 19        https://github.com/ThinkingTransistor/Sigma                   C#
# 20  https://github.com/ashishpatel26/Predictive_Ma...     Jupyter Notebook
# 21      https://github.com/materialsvirtuallab/mlearn               Python
# 22  https://github.com/Vatshayan/MALWARE-DETECTION...     Jupyter Notebook
# 23            https://github.com/DanielBalsam/surv_ai               Python
# 24  https://github.com/gunapandianraj/iOS11-Vision...                Swift
# 25      https://github.com/Bjarten/computer-vision-ND     Jupyter Notebook
# 26             https://github.com/MI2DataLab/survshap     Jupyter Notebook
# 27          https://github.com/GSimas/Deep-LearningAI     Jupyter Notebook
# 28  https://github.com/nithyadurai87/machine_learn...                 HTML
# 29    https://github.com/xluxeq/GPT2-Telegram-Chatbot               Python
# 30  https://github.com/Vettejeep/MSDS696-Masters-F...     Jupyter Notebook
# 31             https://github.com/pkmital/dance2dance               Python
# 32  https://github.com/datascienceid/reinforcement...                 None
# 33     https://github.com/materialsvirtuallab/matcalc               Python
# 34   https://github.com/DependableSystemsLab/TensorFI               Python
# 35    https://github.com/xluxeq/GPT3-Telegram-Chatbot               Python
# 36  https://github.com/chriotte/wearable_stress_cl...                 HTML
# 37  https://github.com/captainzero93/Protect-Image...               Python
# 38            https://github.com/Envirometrix/landmap                    R
# 39         https://github.com/Optixal/CryptoInscriber               Python
# 40   https://github.com/noahgift/edge-computer-vision     Jupyter Notebook
# 41  https://github.com/AxelAli/Tensorflow-Image-Cl...               Python
# 42    https://github.com/aydinnyunus/Machine-Learning     Jupyter Notebook
# 43  https://github.com/luisarojas/distracted-drive...     Jupyter Notebook
# 44  https://github.com/remotesensinginfo/rsgislib-...     Jupyter Notebook
# 45  https://github.com/Jumabek/net_intrusion_detec...     Jupyter Notebook
# 46                  https://github.com/davidawad/lobe               Python
# 47  https://github.com/Projects-Developer/Google-S...     Jupyter Notebook
# 48         https://github.com/ProGamerGov/Neural-Tile                Shell
# 49  https://github.com/google-deepmind/nuclease_de...     Jupyter Notebook
#
#            Creation_Date     Last_Updated_Date  Number_of_Stars  \
# 0   2017-04-07T10:46:50Z  2024-10-06T04:30:47Z            12783
# 1   2017-08-10T04:29:24Z  2024-10-05T15:14:52Z             6114
# 2   2016-11-03T22:39:49Z  2024-10-02T09:01:24Z             1043
# 3   2017-06-10T16:05:45Z  2024-10-02T04:41:22Z              807
# 4   2017-01-15T06:43:17Z  2024-09-25T05:00:44Z              725
# 5   2019-08-20T11:26:09Z  2024-09-11T03:23:32Z              710
# 6   2020-11-08T13:30:47Z  2024-10-02T19:37:31Z              706
# 7   2017-08-12T05:05:33Z  2024-10-05T04:34:20Z              690
# 8   2019-02-11T11:25:57Z  2024-10-05T12:04:01Z              576
# 9   2018-01-23T20:37:19Z  2024-09-23T14:20:54Z              524
# 10  2017-02-14T19:46:39Z  2024-09-16T17:54:48Z              383
# 11  2023-07-07T03:35:39Z  2024-09-30T04:16:49Z              338
# 12  2019-07-10T07:59:07Z  2024-10-03T09:17:40Z              324
# 13  2018-08-18T04:06:21Z  2024-08-17T20:23:50Z              241
# 14  2019-05-27T18:36:29Z  2024-09-21T22:55:13Z              194
# 15  2015-11-11T10:26:28Z  2024-09-25T00:00:28Z              184
# 16  2017-11-01T12:04:54Z  2024-08-15T08:52:22Z              142
# 17  2017-12-05T03:43:15Z  2024-09-02T20:06:27Z              135
# 18  2020-04-18T08:25:04Z  2024-10-02T13:05:14Z              131
# 19  2016-10-29T12:52:48Z  2024-02-04T08:14:54Z              121
# 20  2018-04-05T10:15:35Z  2024-09-18T07:53:47Z              118
# 21  2019-04-25T16:05:49Z  2024-06-12T14:01:48Z              105
# 22  2021-03-21T18:41:34Z  2024-10-05T20:47:54Z               99
# 23  2023-04-16T19:26:26Z  2024-10-02T11:28:41Z               99
# 24  2017-06-25T15:49:25Z  2024-09-15T11:28:04Z               96
# 25  2018-10-04T05:11:31Z  2024-08-09T20:04:36Z               93
# 26  2022-08-03T08:36:27Z  2024-09-25T21:37:34Z               79
# 27  2017-08-29T15:48:01Z  2024-08-28T15:11:28Z               71
# 28  2018-11-10T06:04:16Z  2024-09-01T11:13:01Z               69
# 29  2019-09-30T20:23:00Z  2023-12-28T09:03:24Z               69
# 30  2019-04-30T16:19:26Z  2024-07-01T12:15:50Z               66
# 31  2018-03-31T00:24:20Z  2024-09-23T04:04:10Z               60
# 32  2018-04-14T03:25:00Z  2024-08-24T14:37:42Z               59
# 33  2023-07-25T02:04:04Z  2024-10-03T22:30:24Z               58
# 34  2018-08-28T04:56:18Z  2024-09-04T23:55:29Z               52
# 35  2021-05-28T15:34:33Z  2024-08-12T20:13:25Z               52
# 36  2018-07-03T19:30:46Z  2024-06-13T04:53:40Z               52
# 37  2024-08-10T22:11:01Z  2024-09-29T19:51:28Z               51
# 38  2019-05-24T20:11:10Z  2024-08-08T04:39:17Z               46
# 39  2017-11-12T16:52:19Z  2024-08-12T04:04:40Z               45
# 40  2019-12-13T17:13:12Z  2024-07-12T07:33:11Z               44
# 41  2017-02-18T05:08:08Z  2023-09-06T11:28:57Z               42
# 42  2019-11-27T16:05:19Z  2024-08-17T14:53:47Z               41
# 43  2017-10-17T17:06:12Z  2024-03-27T07:58:31Z               41
# 44  2022-01-23T21:40:18Z  2024-09-19T07:17:29Z               41
# 45  2019-11-19T02:35:11Z  2024-09-25T13:21:34Z               40
# 46  2018-03-02T20:13:23Z  2024-10-03T14:47:31Z               40
# 47  2021-05-11T12:21:07Z  2024-08-23T09:37:40Z               38
# 48  2017-01-12T19:07:56Z  2024-08-12T19:27:07Z               36
# 49  2024-02-21T00:14:12Z  2024-09-18T08:21:35Z               35
#
#     Number_of_Forks  Number_of_Open_Issues  \
# 0              2699                     12
# 1              1005                      4
# 2               167                     14
# 3               106                      2
# 4               110                     16
# 5                79                     14
# 6               284                      2
# 7               232                      7
# 8                63                     30
# 9                55                      4
# 10               84                     51
# 11               76                      3
# 12               32                      4
# 13               15                      2
# 14               26                      6
# 15               40                      5
# 16               28                      1
# 17               21                      5
# 18               81                      1
# 19               13                      4
# 20               86                      3
# 21               27                      1
# 22               11                      0
# 23                3                      0
# 24               13                      0
# 25               45                      0
# 26               15                      9
# 27               57                      0
# 28               49                      1
# 29               17                      1
# 30               28                      0
# 31               10                      0
# 32               29                      1
# 33               10                      3
# 34               23                     14
# 35               34                      2
# 36               35                      3
# 37                4                      0
# 38               13                      6
# 39                4                      0
# 40               18                      3
# 41               14                      0
# 42                8                      0
# 43               20                      0
# 44                4                      3
# 45               14                      0
# 46               10                     18
# 47                4                      0
# 48                8                      2
# 49               11                      0
#
#                                License_Type
# 0                                   Unknown
# 1                        Apache License 2.0
# 2                                   Unknown
# 3                               MIT License
# 4                               MIT License
# 5                               MIT License
# 6                                   Unknown
# 7           GNU General Public License v3.0
# 8                        Apache License 2.0
# 9                               MIT License
# 10                              MIT License
# 11                              MIT License
# 12          GNU General Public License v3.0
# 13          GNU General Public License v3.0
# 14                                  Unknown
# 15                                    Other
# 16                              MIT License
# 17                                  Unknown
# 18                                  Unknown
# 19                                    Other
# 20                                  Unknown
# 21  BSD 3-Clause "New" or "Revised" License
# 22                                  Unknown
# 23                              MIT License
# 24                              MIT License
# 25                                  Unknown
# 26                              MIT License
# 27                              MIT License
# 28                                  Unknown
# 29                                  Unknown
# 30                       Apache License 2.0
# 31                       Apache License 2.0
# 32                                  Unknown
# 33  BSD 3-Clause "New" or "Revised" License
# 34                              MIT License
# 35                                  Unknown
# 36                                  Unknown
# 37                                    Other
# 38                                  Unknown
# 39                              MIT License
# 40                                    Other
# 41                                  Unknown
# 42                                  Unknown
# 43                              MIT License
# 44                              MIT License
# 45                                  Unknown
# 46                                  Unknown
# 47                                  Unknown
# 48                                  Unknown
# 49                       Apache License 2.0

# %% [markdown]
# ## For every Topics

# %%
repository_data = []
for topic in trending_topics:
    data = fetch_repository_data(topic)
    repository_data.extend(data)

# %%
repository_data
# Out:
# [{'Topic': 'machine learning',
#   'Repository_Name': 'mit-deep-learning-book-pdf',
#   'Owner': 'janishar',
#   'Description': 'MIT Deep Learning Book in PDF format (complete and parts) by Ian Goodfellow, Yoshua Bengio and Aaron Courville',
#   'URL': 'https://github.com/janishar/mit-deep-learning-book-pdf',
#   'Programming_Language': 'Java',
#   'Creation_Date': '2017-04-07T10:46:50Z',
#   'Last_Updated_Date': '2024-10-06T04:30:47Z',
#   'Number_of_Stars': 12783,
#   'Number_of_Forks': 2699,
#   'Number_of_Open_Issues': 12,
#   'License_Type': 'Unknown'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'machine-learning-mindmap',
#   'Owner': 'dformoso',
#   'Description': 'A mindmap summarising Machine Learning concepts, from Data Analysis to Deep Learning.',
#   'URL': 'https://github.com/dformoso/machine-learning-mindmap',
#   'Programming_Language': None,
#   'Creation_Date': '2017-08-10T04:29:24Z',
#   'Last_Updated_Date': '2024-10-05T15:14:52Z',
#   'Number_of_Stars': 6114,
#   'Number_of_Forks': 1005,
#   'Number_of_Open_Issues': 4,
#   'License_Type': 'Apache License 2.0'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'rapping-neural-network',
#   'Owner': 'robbiebarrat',
#   'Description': "Rap song writing recurrent neural network trained on Kanye West's entire discography",
#   'URL': 'https://github.com/robbiebarrat/rapping-neural-network',
#   'Programming_Language': 'Python',
#   'Creation_Date': '2016-11-03T22:39:49Z',
#   'Last_Updated_Date': '2024-10-02T09:01:24Z',
#   'Number_of_Stars': 1043,
#   'Number_of_Forks': 167,
#   'Number_of_Open_Issues': 14,
#   'License_Type': 'Unknown'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'awesome-machine-learning',
#   'Owner': 'onmyway133',
#   'Description': '🎰 A curated list of machine learning resources, preferably CoreML',
#   'URL': 'https://github.com/onmyway133/awesome-machine-learning',
#   'Programming_Language': None,
#   'Creation_Date': '2017-06-10T16:05:45Z',
#   'Last_Updated_Date': '2024-10-02T04:41:22Z',
#   'Number_of_Stars': 807,
#   'Number_of_Forks': 106,
#   'Number_of_Open_Issues': 2,
#   'License_Type': 'MIT License'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'DeepJ',
#   'Owner': 'calclavia',
#   'Description': 'A deep learning model for style-specific music generation.',
#   'URL': 'https://github.com/calclavia/DeepJ',
#   'Programming_Language': 'Python',
#   'Creation_Date': '2017-01-15T06:43:17Z',
#   'Last_Updated_Date': '2024-09-25T05:00:44Z',
#   'Number_of_Stars': 725,
#   'Number_of_Forks': 110,
#   'Number_of_Open_Issues': 16,
#   'License_Type': 'MIT License'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'HungaBunga',
#   'Owner': 'ypeleg',
#   'Description': 'HungaBunga: Brute-Force all sklearn models with all parameters using .fit .predict!',
#   'URL': 'https://github.com/ypeleg/HungaBunga',
#   'Programming_Language': 'Python',
#   'Creation_Date': '2019-08-20T11:26:09Z',
#   'Last_Updated_Date': '2024-09-11T03:23:32Z',
#   'Number_of_Stars': 710,
#   'Number_of_Forks': 79,
#   'Number_of_Open_Issues': 14,
#   'License_Type': 'MIT License'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'practical-mlops-book',
#   'Owner': 'paiml',
#   'Description': "[Book-2021] Practical MLOps O'Reilly Book",
#   'URL': 'https://github.com/paiml/practical-mlops-book',
#   'Programming_Language': 'Jupyter Notebook',
#   'Creation_Date': '2020-11-08T13:30:47Z',
#   'Last_Updated_Date': '2024-10-02T19:37:31Z',
#   'Number_of_Stars': 706,
#   'Number_of_Forks': 284,
#   'Number_of_Open_Issues': 2,
#   'License_Type': 'Unknown'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'sklearn-classification',
#   'Owner': 'dformoso',
#   'Description': 'Data Science Notebook on a Classification Task, using sklearn and Tensorflow.',
#   'URL': 'https://github.com/dformoso/sklearn-classification',
#   'Programming_Language': 'Jupyter Notebook',
#   'Creation_Date': '2017-08-12T05:05:33Z',
#   'Last_Updated_Date': '2024-10-05T04:34:20Z',
#   'Number_of_Stars': 690,
#   'Number_of_Forks': 232,
#   'Number_of_Open_Issues': 7,
#   'License_Type': 'GNU General Public License v3.0'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'neptune-client',
#   'Owner': 'neptune-ai',
#   'Description': '📘 The experiment tracker for foundation model training',
#   'URL': 'https://github.com/neptune-ai/neptune-client',
#   'Programming_Language': 'Python',
#   'Creation_Date': '2019-02-11T11:25:57Z',
#   'Last_Updated_Date': '2024-10-05T12:04:01Z',
#   'Number_of_Stars': 576,
#   'Number_of_Forks': 63,
#   'Number_of_Open_Issues': 30,
#   'License_Type': 'Apache License 2.0'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'moviebox',
#   'Owner': 'klaudiosinani',
#   'Description': 'Machine learning movie recommending system',
#   'URL': 'https://github.com/klaudiosinani/moviebox',
#   'Programming_Language': 'Python',
#   'Creation_Date': '2018-01-23T20:37:19Z',
#   'Last_Updated_Date': '2024-09-23T14:20:54Z',
#   'Number_of_Stars': 524,
#   'Number_of_Forks': 55,
#   'Number_of_Open_Issues': 4,
#   'License_Type': 'MIT License'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'SharpLearning',
#   'Owner': 'mdabros',
#   'Description': 'Machine learning for C# .Net  ',
#   'URL': 'https://github.com/mdabros/SharpLearning',
#   'Programming_Language': 'C#',
#   'Creation_Date': '2017-02-14T19:46:39Z',
#   'Last_Updated_Date': '2024-09-16T17:54:48Z',
#   'Number_of_Stars': 383,
#   'Number_of_Forks': 84,
#   'Number_of_Open_Issues': 51,
#   'License_Type': 'MIT License'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'opml',
#   'Owner': 'ora-io',
#   'Description': 'OPML: OPtimistic Machine Learning on Blockchain',
#   'URL': 'https://github.com/ora-io/opml',
#   'Programming_Language': 'Solidity',
#   'Creation_Date': '2023-07-07T03:35:39Z',
#   'Last_Updated_Date': '2024-09-30T04:16:49Z',
#   'Number_of_Stars': 338,
#   'Number_of_Forks': 76,
#   'Number_of_Open_Issues': 3,
#   'License_Type': 'MIT License'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'modelStudio',
#   'Owner': 'ModelOriented',
#   'Description': '📍 Interactive Studio for Explanatory Model Analysis',
#   'URL': 'https://github.com/ModelOriented/modelStudio',
#   'Programming_Language': 'R',
#   'Creation_Date': '2019-07-10T07:59:07Z',
#   'Last_Updated_Date': '2024-10-03T09:17:40Z',
#   'Number_of_Stars': 324,
#   'Number_of_Forks': 32,
#   'Number_of_Open_Issues': 4,
#   'License_Type': 'GNU General Public License v3.0'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'DeepSort',
#   'Owner': 'CorentinB',
#   'Description': '🧠 AI powered image tagger backed by DeepDetect',
#   'URL': 'https://github.com/CorentinB/DeepSort',
#   'Programming_Language': 'Go',
#   'Creation_Date': '2018-08-18T04:06:21Z',
#   'Last_Updated_Date': '2024-08-17T20:23:50Z',
#   'Number_of_Stars': 241,
#   'Number_of_Forks': 15,
#   'Number_of_Open_Issues': 2,
#   'License_Type': 'GNU General Public License v3.0'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'mrcl',
#   'Owner': 'khurramjaved96',
#   'Description': 'Code for the NeurIPS19 paper "Meta-Learning Representations for Continual Learning"',
#   'URL': 'https://github.com/khurramjaved96/mrcl',
#   'Programming_Language': 'Python',
#   'Creation_Date': '2019-05-27T18:36:29Z',
#   'Last_Updated_Date': '2024-09-21T22:55:13Z',
#   'Number_of_Stars': 194,
#   'Number_of_Forks': 26,
#   'Number_of_Open_Issues': 6,
#   'License_Type': 'Unknown'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'Retro-Learning-Environment',
#   'Owner': 'nadavbh12',
#   'Description': 'The Retro Learning Environment (RLE) -- a learning framework for AI',
#   'URL': 'https://github.com/nadavbh12/Retro-Learning-Environment',
#   'Programming_Language': 'C++',
#   'Creation_Date': '2015-11-11T10:26:28Z',
#   'Last_Updated_Date': '2024-09-25T00:00:28Z',
#   'Number_of_Stars': 184,
#   'Number_of_Forks': 40,
#   'Number_of_Open_Issues': 5,
#   'License_Type': 'Other'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'Makine-Ogrenmesi',
#   'Owner': 'SerayBeser',
#   'Description': 'Makine Öğrenmesi Türkçe Kaynak',
#   'URL': 'https://github.com/SerayBeser/Makine-Ogrenmesi',
#   'Programming_Language': 'Python',
#   'Creation_Date': '2017-11-01T12:04:54Z',
#   'Last_Updated_Date': '2024-08-15T08:52:22Z',
#   'Number_of_Stars': 142,
#   'Number_of_Forks': 28,
#   'Number_of_Open_Issues': 1,
#   'License_Type': 'MIT License'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'scenescoop',
#   'Owner': 'cvalenzuela',
#   'Description': 'A tool to describe the content of videos and suggest similar scenes in other videos/films.',
#   'URL': 'https://github.com/cvalenzuela/scenescoop',
#   'Programming_Language': 'Python',
#   'Creation_Date': '2017-12-05T03:43:15Z',
#   'Last_Updated_Date': '2024-09-02T20:06:27Z',
#   'Number_of_Stars': 135,
#   'Number_of_Forks': 21,
#   'Number_of_Open_Issues': 5,
#   'License_Type': 'Unknown'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'practical-ml-for-cybersecurity',
#   'Owner': 'shramos',
#   'Description': 'More than twenty practical cases with real datasets of application of Machine Learning to the field of Cybersecurity',
#   'URL': 'https://github.com/shramos/practical-ml-for-cybersecurity',
#   'Programming_Language': 'Jupyter Notebook',
#   'Creation_Date': '2020-04-18T08:25:04Z',
#   'Last_Updated_Date': '2024-10-02T13:05:14Z',
#   'Number_of_Stars': 131,
#   'Number_of_Forks': 81,
#   'Number_of_Open_Issues': 1,
#   'License_Type': 'Unknown'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'Sigma',
#   'Owner': 'ThinkingTransistor',
#   'Description': 'Rocket powered machine learning. Create, compare, adapt, improve - artificial intelligence at the speed of thought.',
#   'URL': 'https://github.com/ThinkingTransistor/Sigma',
#   'Programming_Language': 'C#',
#   'Creation_Date': '2016-10-29T12:52:48Z',
#   'Last_Updated_Date': '2024-02-04T08:14:54Z',
#   'Number_of_Stars': 121,
#   'Number_of_Forks': 13,
#   'Number_of_Open_Issues': 4,
#   'License_Type': 'Other'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'Predictive_Maintenance_using_Machine-Learning_Microsoft_Casestudy',
#   'Owner': 'ashishpatel26',
#   'Description': 'Predictive_Maintenance_using_Machine-Learning_Microsoft_Casestudy',
#   'URL': 'https://github.com/ashishpatel26/Predictive_Maintenance_using_Machine-Learning_Microsoft_Casestudy',
#   'Programming_Language': 'Jupyter Notebook',
#   'Creation_Date': '2018-04-05T10:15:35Z',
#   'Last_Updated_Date': '2024-09-18T07:53:47Z',
#   'Number_of_Stars': 118,
#   'Number_of_Forks': 86,
#   'Number_of_Open_Issues': 3,
#   'License_Type': 'Unknown'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'mlearn',
#   'Owner': 'materialsvirtuallab',
#   'Description': 'Benchmark Suite for Machine Learning Interatomic Potentials for Materials',
#   'URL': 'https://github.com/materialsvirtuallab/mlearn',
#   'Programming_Language': 'Python',
#   'Creation_Date': '2019-04-25T16:05:49Z',
#   'Last_Updated_Date': '2024-06-12T14:01:48Z',
#   'Number_of_Stars': 105,
#   'Number_of_Forks': 27,
#   'Number_of_Open_Issues': 1,
#   'License_Type': 'BSD 3-Clause "New" or "Revised" License'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'MALWARE-DETECTION-FINAL-YEAR-PROJECT',
#   'Owner': 'Vatshayan',
#   'Description': 'Final Year Malware Detection Project with PPT, Research Paper, code and Synopsis. Malware detection project by Machine Learning ALgorithms.',
#   'URL': 'https://github.com/Vatshayan/MALWARE-DETECTION-FINAL-YEAR-PROJECT',
#   'Programming_Language': 'Jupyter Notebook',
#   'Creation_Date': '2021-03-21T18:41:34Z',
#   'Last_Updated_Date': '2024-10-05T20:47:54Z',
#   'Number_of_Stars': 99,
#   'Number_of_Forks': 11,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'Unknown'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'surv_ai',
#   'Owner': 'DanielBalsam',
#   'Description': 'A framework to empower forecasting using Large Language Models (LLMs)',
#   'URL': 'https://github.com/DanielBalsam/surv_ai',
#   'Programming_Language': 'Python',
#   'Creation_Date': '2023-04-16T19:26:26Z',
#   'Last_Updated_Date': '2024-10-02T11:28:41Z',
#   'Number_of_Stars': 99,
#   'Number_of_Forks': 3,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'MIT License'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'iOS11-VisionFrameWork',
#   'Owner': 'gunapandianraj',
#   'Description': 'Vision Framework IOS WWDC 2017',
#   'URL': 'https://github.com/gunapandianraj/iOS11-VisionFrameWork',
#   'Programming_Language': 'Swift',
#   'Creation_Date': '2017-06-25T15:49:25Z',
#   'Last_Updated_Date': '2024-09-15T11:28:04Z',
#   'Number_of_Stars': 96,
#   'Number_of_Forks': 13,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'MIT License'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'computer-vision-ND',
#   'Owner': 'Bjarten',
#   'Description': 'Projects and exercises for the Udacity Computer Vision Nanodegree',
#   'URL': 'https://github.com/Bjarten/computer-vision-ND',
#   'Programming_Language': 'Jupyter Notebook',
#   'Creation_Date': '2018-10-04T05:11:31Z',
#   'Last_Updated_Date': '2024-08-09T20:04:36Z',
#   'Number_of_Stars': 93,
#   'Number_of_Forks': 45,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'Unknown'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'survshap',
#   'Owner': 'MI2DataLab',
#   'Description': 'SurvSHAP(t): Time-dependent explanations of machine learning survival models',
#   'URL': 'https://github.com/MI2DataLab/survshap',
#   'Programming_Language': 'Jupyter Notebook',
#   'Creation_Date': '2022-08-03T08:36:27Z',
#   'Last_Updated_Date': '2024-09-25T21:37:34Z',
#   'Number_of_Stars': 79,
#   'Number_of_Forks': 15,
#   'Number_of_Open_Issues': 9,
#   'License_Type': 'MIT License'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'Deep-LearningAI',
#   'Owner': 'GSimas',
#   'Description': '🇦🇮 Deep Learning AI course on Coursera (Andrew Ng)',
#   'URL': 'https://github.com/GSimas/Deep-LearningAI',
#   'Programming_Language': 'Jupyter Notebook',
#   'Creation_Date': '2017-08-29T15:48:01Z',
#   'Last_Updated_Date': '2024-08-28T15:11:28Z',
#   'Number_of_Stars': 71,
#   'Number_of_Forks': 57,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'MIT License'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'machine_learning_examples',
#   'Owner': 'nithyadurai87',
#   'Description': 'machine_learning_examples',
#   'URL': 'https://github.com/nithyadurai87/machine_learning_examples',
#   'Programming_Language': 'HTML',
#   'Creation_Date': '2018-11-10T06:04:16Z',
#   'Last_Updated_Date': '2024-09-01T11:13:01Z',
#   'Number_of_Stars': 69,
#   'Number_of_Forks': 49,
#   'Number_of_Open_Issues': 1,
#   'License_Type': 'Unknown'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'GPT2-Telegram-Chatbot',
#   'Owner': 'xluxeq',
#   'Description': 'GPT-2 Telegram Chat bot',
#   'URL': 'https://github.com/xluxeq/GPT2-Telegram-Chatbot',
#   'Programming_Language': 'Python',
#   'Creation_Date': '2019-09-30T20:23:00Z',
#   'Last_Updated_Date': '2023-12-28T09:03:24Z',
#   'Number_of_Stars': 69,
#   'Number_of_Forks': 17,
#   'Number_of_Open_Issues': 1,
#   'License_Type': 'Unknown'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'MSDS696-Masters-Final-Project',
#   'Owner': 'Vettejeep',
#   'Description': 'Earthquake Prediction Challenge with LightGBM and XGBoost',
#   'URL': 'https://github.com/Vettejeep/MSDS696-Masters-Final-Project',
#   'Programming_Language': 'Jupyter Notebook',
#   'Creation_Date': '2019-04-30T16:19:26Z',
#   'Last_Updated_Date': '2024-07-01T12:15:50Z',
#   'Number_of_Stars': 66,
#   'Number_of_Forks': 28,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'Apache License 2.0'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'dance2dance',
#   'Owner': 'pkmital',
#   'Description': 'Discrete Figures AI: Seq2Seq of Dance Data (Mikiko + Daito Manabe + Kyle McDonald)',
#   'URL': 'https://github.com/pkmital/dance2dance',
#   'Programming_Language': 'Python',
#   'Creation_Date': '2018-03-31T00:24:20Z',
#   'Last_Updated_Date': '2024-09-23T04:04:10Z',
#   'Number_of_Stars': 60,
#   'Number_of_Forks': 10,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'Apache License 2.0'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'reinforcement-learning-resources',
#   'Owner': 'datascienceid',
#   'Description': 'A curated list of awesome reinforcement courses, video lectures, books, library and many more. ',
#   'URL': 'https://github.com/datascienceid/reinforcement-learning-resources',
#   'Programming_Language': None,
#   'Creation_Date': '2018-04-14T03:25:00Z',
#   'Last_Updated_Date': '2024-08-24T14:37:42Z',
#   'Number_of_Stars': 59,
#   'Number_of_Forks': 29,
#   'Number_of_Open_Issues': 1,
#   'License_Type': 'Unknown'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'matcalc',
#   'Owner': 'materialsvirtuallab',
#   'Description': 'A python library for calculating materials properties from the PES',
#   'URL': 'https://github.com/materialsvirtuallab/matcalc',
#   'Programming_Language': 'Python',
#   'Creation_Date': '2023-07-25T02:04:04Z',
#   'Last_Updated_Date': '2024-10-03T22:30:24Z',
#   'Number_of_Stars': 58,
#   'Number_of_Forks': 10,
#   'Number_of_Open_Issues': 3,
#   'License_Type': 'BSD 3-Clause "New" or "Revised" License'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'TensorFI',
#   'Owner': 'DependableSystemsLab',
#   'Description': 'TensorFI is a fault injection framework for injecting both hardware and software faults into applications written using the TensorFlow framework. You can find more information about TensorFI in the paper below.',
#   'URL': 'https://github.com/DependableSystemsLab/TensorFI',
#   'Programming_Language': 'Python',
#   'Creation_Date': '2018-08-28T04:56:18Z',
#   'Last_Updated_Date': '2024-09-04T23:55:29Z',
#   'Number_of_Stars': 52,
#   'Number_of_Forks': 23,
#   'Number_of_Open_Issues': 14,
#   'License_Type': 'MIT License'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'GPT3-Telegram-Chatbot',
#   'Owner': 'xluxeq',
#   'Description': 'OpenAI chatbot for Telegram using GPT-3.',
#   'URL': 'https://github.com/xluxeq/GPT3-Telegram-Chatbot',
#   'Programming_Language': 'Python',
#   'Creation_Date': '2021-05-28T15:34:33Z',
#   'Last_Updated_Date': '2024-08-12T20:13:25Z',
#   'Number_of_Stars': 52,
#   'Number_of_Forks': 34,
#   'Number_of_Open_Issues': 2,
#   'License_Type': 'Unknown'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'wearable_stress_classification',
#   'Owner': 'chriotte',
#   'Description': 'Stress classifier with AutoML',
#   'URL': 'https://github.com/chriotte/wearable_stress_classification',
#   'Programming_Language': 'HTML',
#   'Creation_Date': '2018-07-03T19:30:46Z',
#   'Last_Updated_Date': '2024-06-13T04:53:40Z',
#   'Number_of_Stars': 52,
#   'Number_of_Forks': 35,
#   'Number_of_Open_Issues': 3,
#   'License_Type': 'Unknown'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'Protect-Images-from-AI-PixelGuard',
#   'Owner': 'captainzero93',
#   'Description': 'PixelGuard protects images from AI scraping and unauthorized use in AI training, such as facial recognition models or style transfer algorithms. It employs multiple invisible protection techniques that mostly imperceptible to the eye but can interfere with AI processing.',
#   'URL': 'https://github.com/captainzero93/Protect-Images-from-AI-PixelGuard',
#   'Programming_Language': 'Python',
#   'Creation_Date': '2024-08-10T22:11:01Z',
#   'Last_Updated_Date': '2024-09-29T19:51:28Z',
#   'Number_of_Stars': 51,
#   'Number_of_Forks': 4,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'Other'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'landmap',
#   'Owner': 'Envirometrix',
#   'Description': 'Landmap package for R',
#   'URL': 'https://github.com/Envirometrix/landmap',
#   'Programming_Language': 'R',
#   'Creation_Date': '2019-05-24T20:11:10Z',
#   'Last_Updated_Date': '2024-08-08T04:39:17Z',
#   'Number_of_Stars': 46,
#   'Number_of_Forks': 13,
#   'Number_of_Open_Issues': 6,
#   'License_Type': 'Unknown'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'CryptoInscriber',
#   'Owner': 'Optixal',
#   'Description': ':chart_with_upwards_trend: A live cryptocurrency historical trade data blotter. Download live historical trade data from any cryptoexchange, be it for machine learning, backtesting/visualizing trading strategies or for Quantopian/Zipline.',
#   'URL': 'https://github.com/Optixal/CryptoInscriber',
#   'Programming_Language': 'Python',
#   'Creation_Date': '2017-11-12T16:52:19Z',
#   'Last_Updated_Date': '2024-08-12T04:04:40Z',
#   'Number_of_Stars': 45,
#   'Number_of_Forks': 4,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'MIT License'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'edge-computer-vision',
#   'Owner': 'noahgift',
#   'Description': 'Edge Computer Vision Course',
#   'URL': 'https://github.com/noahgift/edge-computer-vision',
#   'Programming_Language': 'Jupyter Notebook',
#   'Creation_Date': '2019-12-13T17:13:12Z',
#   'Last_Updated_Date': '2024-07-12T07:33:11Z',
#   'Number_of_Stars': 44,
#   'Number_of_Forks': 18,
#   'Number_of_Open_Issues': 3,
#   'License_Type': 'Other'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'Tensorflow-Image-Classification',
#   'Owner': 'AxelAli',
#   'Description': 'Easy/Updated Tensorflow Image Classification',
#   'URL': 'https://github.com/AxelAli/Tensorflow-Image-Classification',
#   'Programming_Language': 'Python',
#   'Creation_Date': '2017-02-18T05:08:08Z',
#   'Last_Updated_Date': '2023-09-06T11:28:57Z',
#   'Number_of_Stars': 42,
#   'Number_of_Forks': 14,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'Unknown'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'Machine-Learning',
#   'Owner': 'aydinnyunus',
#   'Description': 'Machine Learning (Easy to Hard step by step)',
#   'URL': 'https://github.com/aydinnyunus/Machine-Learning',
#   'Programming_Language': 'Jupyter Notebook',
#   'Creation_Date': '2019-11-27T16:05:19Z',
#   'Last_Updated_Date': '2024-08-17T14:53:47Z',
#   'Number_of_Stars': 41,
#   'Number_of_Forks': 8,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'Unknown'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'distracted-driver-detection',
#   'Owner': 'luisarojas',
#   'Description': 'Predicting the likelihood of what the driver is doing in each of the pictures in the dataset.',
#   'URL': 'https://github.com/luisarojas/distracted-driver-detection',
#   'Programming_Language': 'Jupyter Notebook',
#   'Creation_Date': '2017-10-17T17:06:12Z',
#   'Last_Updated_Date': '2024-03-27T07:58:31Z',
#   'Number_of_Stars': 41,
#   'Number_of_Forks': 20,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'MIT License'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'rsgislib-tutorials',
#   'Owner': 'remotesensinginfo',
#   'Description': 'A set of notebook tutorials for RSGISLib.',
#   'URL': 'https://github.com/remotesensinginfo/rsgislib-tutorials',
#   'Programming_Language': 'Jupyter Notebook',
#   'Creation_Date': '2022-01-23T21:40:18Z',
#   'Last_Updated_Date': '2024-09-19T07:17:29Z',
#   'Number_of_Stars': 41,
#   'Number_of_Forks': 4,
#   'Number_of_Open_Issues': 3,
#   'License_Type': 'MIT License'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'net_intrusion_detection',
#   'Owner': 'Jumabek',
#   'Description': 'Network intrusion detection with Machine Learning (Deep Learning) experiment : 1d-cnn, softmax, neural networks, convolution',
#   'URL': 'https://github.com/Jumabek/net_intrusion_detection',
#   'Programming_Language': 'Jupyter Notebook',
#   'Creation_Date': '2019-11-19T02:35:11Z',
#   'Last_Updated_Date': '2024-09-25T13:21:34Z',
#   'Number_of_Stars': 40,
#   'Number_of_Forks': 14,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'Unknown'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'lobe',
#   'Owner': 'davidawad',
#   'Description': "Lobe is the world's first AI paralegal. ",
#   'URL': 'https://github.com/davidawad/lobe',
#   'Programming_Language': 'Python',
#   'Creation_Date': '2018-03-02T20:13:23Z',
#   'Last_Updated_Date': '2024-10-03T14:47:31Z',
#   'Number_of_Stars': 40,
#   'Number_of_Forks': 10,
#   'Number_of_Open_Issues': 18,
#   'License_Type': 'Unknown'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'Google-Stock-Price-Prediction-by-Deep-Learning',
#   'Owner': 'Projects-Developer',
#   'Description': 'Top Class Stock Price Prediction Project through Machine Learning Algorithms for Google. Easy Understanding and Implementation. B.tech Final Year College Project. ',
#   'URL': 'https://github.com/Projects-Developer/Google-Stock-Price-Prediction-by-Deep-Learning',
#   'Programming_Language': 'Jupyter Notebook',
#   'Creation_Date': '2021-05-11T12:21:07Z',
#   'Last_Updated_Date': '2024-08-23T09:37:40Z',
#   'Number_of_Stars': 38,
#   'Number_of_Forks': 4,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'Unknown'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'Neural-Tile',
#   'Owner': 'ProGamerGov',
#   'Description': 'A better tiling script for Neural-Style',
#   'URL': 'https://github.com/ProGamerGov/Neural-Tile',
#   'Programming_Language': 'Shell',
#   'Creation_Date': '2017-01-12T19:07:56Z',
#   'Last_Updated_Date': '2024-08-12T19:27:07Z',
#   'Number_of_Stars': 36,
#   'Number_of_Forks': 8,
#   'Number_of_Open_Issues': 2,
#   'License_Type': 'Unknown'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'nuclease_design',
#   'Owner': 'google-deepmind',
#   'Description': 'ML-guided enzyme engineering',
#   'URL': 'https://github.com/google-deepmind/nuclease_design',
#   'Programming_Language': 'Jupyter Notebook',
#   'Creation_Date': '2024-02-21T00:14:12Z',
#   'Last_Updated_Date': '2024-09-18T08:21:35Z',
#   'Number_of_Stars': 35,
#   'Number_of_Forks': 11,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'Apache License 2.0'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'choice-learn',
#   'Owner': 'artefactory',
#   'Description': 'Discrete choice modeling in Python with large datasets & models - Assortment & Pricing Optimization .',
#   'URL': 'https://github.com/artefactory/choice-learn',
#   'Programming_Language': 'Python',
#   'Creation_Date': '2023-12-18T13:09:29Z',
#   'Last_Updated_Date': '2024-10-03T15:21:18Z',
#   'Number_of_Stars': 35,
#   'Number_of_Forks': 3,
#   'Number_of_Open_Issues': 7,
#   'License_Type': 'MIT License'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'JPMC-Quant-Challenge-2022',
#   'Owner': 'aaryan2134',
#   'Description': ' J.P. Morgan Quant Challenge 2022 Questions',
#   'URL': 'https://github.com/aaryan2134/JPMC-Quant-Challenge-2022',
#   'Programming_Language': None,
#   'Creation_Date': '2022-09-13T18:35:24Z',
#   'Last_Updated_Date': '2024-09-08T08:51:50Z',
#   'Number_of_Stars': 34,
#   'Number_of_Forks': 18,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'MIT License'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'uLAPack',
#   'Owner': 'SargisYonan',
#   'Description': 'Micro Linear Algebra Package',
#   'URL': 'https://github.com/SargisYonan/uLAPack',
#   'Programming_Language': 'C',
#   'Creation_Date': '2019-01-08T23:02:03Z',
#   'Last_Updated_Date': '2024-08-27T13:14:16Z',
#   'Number_of_Stars': 34,
#   'Number_of_Forks': 11,
#   'Number_of_Open_Issues': 2,
#   'License_Type': 'Other'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'MNIST-Machine-Learning',
#   'Owner': 'mikepallister',
#   'Description': 'Machine Learning MNIST Digits with a Neural Network in Excel',
#   'URL': 'https://github.com/mikepallister/MNIST-Machine-Learning',
#   'Programming_Language': None,
#   'Creation_Date': '2017-12-22T16:49:29Z',
#   'Last_Updated_Date': '2024-08-29T00:40:50Z',
#   'Number_of_Stars': 27,
#   'Number_of_Forks': 11,
#   'Number_of_Open_Issues': 4,
#   'License_Type': 'Unknown'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'simple-image-classifier',
#   'Owner': 'gbnk0',
#   'Description': 'Simple image classifier microservice using tensorflow and sanic',
#   'URL': 'https://github.com/gbnk0/simple-image-classifier',
#   'Programming_Language': 'Python',
#   'Creation_Date': '2018-07-18T20:49:51Z',
#   'Last_Updated_Date': '2023-12-14T14:39:53Z',
#   'Number_of_Stars': 25,
#   'Number_of_Forks': 8,
#   'Number_of_Open_Issues': 4,
#   'License_Type': 'MIT License'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'thesaurus',
#   'Owner': 'mitevpi',
#   'Description': 'TT Hackathon 2018 - Autocomplete for Visual Programming Nodes',
#   'URL': 'https://github.com/mitevpi/thesaurus',
#   'Programming_Language': 'C#',
#   'Creation_Date': '2018-10-27T15:45:33Z',
#   'Last_Updated_Date': '2024-05-18T22:22:06Z',
#   'Number_of_Stars': 25,
#   'Number_of_Forks': 7,
#   'Number_of_Open_Issues': 4,
#   'License_Type': 'MIT License'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'Mia',
#   'Owner': 'byroneverson',
#   'Description': 'A simple swift app for MacOS/iOS to test large language models (LLM)',
#   'URL': 'https://github.com/byroneverson/Mia',
#   'Programming_Language': 'Swift',
#   'Creation_Date': '2023-04-28T20:51:57Z',
#   'Last_Updated_Date': '2024-09-14T15:27:05Z',
#   'Number_of_Stars': 23,
#   'Number_of_Forks': 1,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'Unknown'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'Reproducible-Bayesian-Tensor-Matrix-Machine-Learning-SOTA',
#   'Owner': 'leicheng-tensor',
#   'Description': 'Reproducible-Bayesian-Tensor-Machine-Learning-SOTA',
#   'URL': 'https://github.com/leicheng-tensor/Reproducible-Bayesian-Tensor-Matrix-Machine-Learning-SOTA',
#   'Programming_Language': None,
#   'Creation_Date': '2022-04-26T03:20:27Z',
#   'Last_Updated_Date': '2024-07-26T08:29:59Z',
#   'Number_of_Stars': 22,
#   'Number_of_Forks': 8,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'Unknown'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'Credit-Risk-Modelling',
#   'Owner': 'RegaipKURT',
#   'Description': None,
#   'URL': 'https://github.com/RegaipKURT/Credit-Risk-Modelling',
#   'Programming_Language': 'Jupyter Notebook',
#   'Creation_Date': '2020-07-07T22:55:10Z',
#   'Last_Updated_Date': '2024-09-24T05:34:44Z',
#   'Number_of_Stars': 22,
#   'Number_of_Forks': 8,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'Unknown'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'mlhowto',
#   'Owner': 'pmarquees',
#   'Description': 'This are the steps I took into Machine Learning ',
#   'URL': 'https://github.com/pmarquees/mlhowto',
#   'Programming_Language': None,
#   'Creation_Date': '2018-10-15T16:09:54Z',
#   'Last_Updated_Date': '2023-11-16T11:08:41Z',
#   'Number_of_Stars': 21,
#   'Number_of_Forks': 1,
#   'Number_of_Open_Issues': 1,
#   'License_Type': 'Unknown'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'mex-vocabulary',
#   'Owner': 'mexplatform',
#   'Description': 'MEX Vocabulary: a lightweight machine learning interchange format',
#   'URL': 'https://github.com/mexplatform/mex-vocabulary',
#   'Programming_Language': 'HTML',
#   'Creation_Date': '2015-03-30T22:56:03Z',
#   'Last_Updated_Date': '2022-01-27T11:19:55Z',
#   'Number_of_Stars': 20,
#   'Number_of_Forks': 11,
#   'Number_of_Open_Issues': 9,
#   'License_Type': 'GNU General Public License v3.0'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'radtorch',
#   'Owner': 'radtorch',
#   'Description': 'Official repository for RADTorch - The Medical Imaging Machine Learning Framework',
#   'URL': 'https://github.com/radtorch/radtorch',
#   'Programming_Language': 'Python',
#   'Creation_Date': '2020-02-16T02:44:31Z',
#   'Last_Updated_Date': '2024-08-30T12:21:10Z',
#   'Number_of_Stars': 20,
#   'Number_of_Forks': 5,
#   'Number_of_Open_Issues': 1,
#   'License_Type': 'Other'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'Disease-Prediction-Project-using-Machine-Learning-Project',
#   'Owner': 'Vatshayan',
#   'Description': 'Diseases Prediction System though Machine Learning with code and documents',
#   'URL': 'https://github.com/Vatshayan/Disease-Prediction-Project-using-Machine-Learning-Project',
#   'Programming_Language': 'Jupyter Notebook',
#   'Creation_Date': '2021-03-13T21:07:01Z',
#   'Last_Updated_Date': '2024-10-03T22:36:45Z',
#   'Number_of_Stars': 20,
#   'Number_of_Forks': 0,
#   'Number_of_Open_Issues': 3,
#   'License_Type': 'Unknown'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'Datacamp',
#   'Owner': 'AnuragAnalog',
#   'Description': 'My Solutions to Datacamp projects and courses(datacamp-exercises)',
#   'URL': 'https://github.com/AnuragAnalog/Datacamp',
#   'Programming_Language': 'Jupyter Notebook',
#   'Creation_Date': '2020-01-29T06:00:10Z',
#   'Last_Updated_Date': '2024-09-10T15:13:14Z',
#   'Number_of_Stars': 20,
#   'Number_of_Forks': 7,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'GNU General Public License v3.0'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'spatial-prediction-eml',
#   'Owner': 'OpenGeoHub',
#   'Description': 'Online tutorial on how to use Ensemble Machine Learning for spatial and spatiotemporal interpolation / predictions',
#   'URL': 'https://github.com/OpenGeoHub/spatial-prediction-eml',
#   'Programming_Language': 'TeX',
#   'Creation_Date': '2022-01-14T10:59:12Z',
#   'Last_Updated_Date': '2024-04-24T10:42:57Z',
#   'Number_of_Stars': 19,
#   'Number_of_Forks': 10,
#   'Number_of_Open_Issues': 3,
#   'License_Type': 'Other'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'MLcourse',
#   'Owner': 'abhijithneilabraham',
#   'Description': 'A machine learning course flow that will make you more curious after I teach you!',
#   'URL': 'https://github.com/abhijithneilabraham/MLcourse',
#   'Programming_Language': None,
#   'Creation_Date': '2018-10-07T17:29:45Z',
#   'Last_Updated_Date': '2023-10-11T09:44:05Z',
#   'Number_of_Stars': 18,
#   'Number_of_Forks': 12,
#   'Number_of_Open_Issues': 6,
#   'License_Type': 'Unknown'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'knime-r',
#   'Owner': 'knime',
#   'Description': 'KNIME Interactive R Statistics Integration',
#   'URL': 'https://github.com/knime/knime-r',
#   'Programming_Language': 'HTML',
#   'Creation_Date': '2017-09-04T06:51:35Z',
#   'Last_Updated_Date': '2024-09-11T23:53:23Z',
#   'Number_of_Stars': 18,
#   'Number_of_Forks': 8,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'Other'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'PredictMD.jl',
#   'Owner': 'bcbi',
#   'Description': 'Uniform interface for machine learning in Julia',
#   'URL': 'https://github.com/bcbi/PredictMD.jl',
#   'Programming_Language': 'Julia',
#   'Creation_Date': '2017-11-04T02:22:54Z',
#   'Last_Updated_Date': '2024-09-16T15:34:49Z',
#   'Number_of_Stars': 18,
#   'Number_of_Forks': 4,
#   'Number_of_Open_Issues': 12,
#   'License_Type': 'MIT License'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'synology-tagger',
#   'Owner': 'eleonne',
#   'Description': 'A Python Machine Learning script to tag pictures in a Synology NAS.',
#   'URL': 'https://github.com/eleonne/synology-tagger',
#   'Programming_Language': 'JavaScript',
#   'Creation_Date': '2023-02-15T17:06:57Z',
#   'Last_Updated_Date': '2024-09-15T14:40:50Z',
#   'Number_of_Stars': 18,
#   'Number_of_Forks': 2,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'Apache License 2.0'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'aws-iot-greengrass-v2-deploy-nvidia-deepstream',
#   'Owner': 'aws-samples',
#   'Description': 'How to use AWS IoT Greengrass V2 for Image classification and Video Analytics Pipelines',
#   'URL': 'https://github.com/aws-samples/aws-iot-greengrass-v2-deploy-nvidia-deepstream',
#   'Programming_Language': 'C',
#   'Creation_Date': '2020-12-21T01:46:09Z',
#   'Last_Updated_Date': '2023-07-25T15:10:01Z',
#   'Number_of_Stars': 17,
#   'Number_of_Forks': 6,
#   'Number_of_Open_Issues': 4,
#   'License_Type': 'MIT No Attribution'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'tv-show-recommendations',
#   'Owner': 'itsjafer',
#   'Description': 'Machine learning pipeline trained offline that, given a TV Show, recommends 10 similar TV Shows using cosine similarities based on a variety of features',
#   'URL': 'https://github.com/itsjafer/tv-show-recommendations',
#   'Programming_Language': 'Python',
#   'Creation_Date': '2019-05-24T20:43:12Z',
#   'Last_Updated_Date': '2024-07-18T19:29:17Z',
#   'Number_of_Stars': 17,
#   'Number_of_Forks': 1,
#   'Number_of_Open_Issues': 2,
#   'License_Type': 'Unknown'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'medbot',
#   'Owner': 'janakajain',
#   'Description': 'This repository is a collection of resources, code-books and illustrations on MediBo project - a medical chatbot capstone project by a group of Columbia University students',
#   'URL': 'https://github.com/janakajain/medbot',
#   'Programming_Language': 'Jupyter Notebook',
#   'Creation_Date': '2017-10-10T20:15:35Z',
#   'Last_Updated_Date': '2024-09-25T01:58:11Z',
#   'Number_of_Stars': 16,
#   'Number_of_Forks': 10,
#   'Number_of_Open_Issues': 1,
#   'License_Type': 'Unknown'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'brain-tumor-classification',
#   'Owner': 'Hassi34',
#   'Description': 'This project contains the production ready Machine Learning(Deep Learning) solution for detecting and classifying the brain tumor in medical images',
#   'URL': 'https://github.com/Hassi34/brain-tumor-classification',
#   'Programming_Language': 'Python',
#   'Creation_Date': '2023-04-28T08:47:06Z',
#   'Last_Updated_Date': '2024-09-29T08:18:39Z',
#   'Number_of_Stars': 16,
#   'Number_of_Forks': 4,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'MIT License'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'awesome-vehicle-datasets',
#   'Owner': 'mdhaisne',
#   'Description': 'A topic-centric list of Vehicles datasets.',
#   'URL': 'https://github.com/mdhaisne/awesome-vehicle-datasets',
#   'Programming_Language': None,
#   'Creation_Date': '2020-02-21T08:51:32Z',
#   'Last_Updated_Date': '2024-08-03T02:26:28Z',
#   'Number_of_Stars': 16,
#   'Number_of_Forks': 2,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'Apache License 2.0'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'ml_classifiers',
#   'Owner': 'lnutimura',
#   'Description': 'A Snort 3 Machine Learning-based Inspector for Bidirectional Network Flow Classification.',
#   'URL': 'https://github.com/lnutimura/ml_classifiers',
#   'Programming_Language': 'C++',
#   'Creation_Date': '2019-08-01T17:16:26Z',
#   'Last_Updated_Date': '2024-09-03T13:03:56Z',
#   'Number_of_Stars': 16,
#   'Number_of_Forks': 2,
#   'Number_of_Open_Issues': 4,
#   'License_Type': 'GNU General Public License v3.0'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'DrBERT',
#   'Owner': 'qanastek',
#   'Description': 'DrBERT: A Robust Pre-trained Model in French for Biomedical and Clinical domains',
#   'URL': 'https://github.com/qanastek/DrBERT',
#   'Programming_Language': 'Python',
#   'Creation_Date': '2023-01-05T15:46:45Z',
#   'Last_Updated_Date': '2024-06-28T12:36:05Z',
#   'Number_of_Stars': 16,
#   'Number_of_Forks': 1,
#   'Number_of_Open_Issues': 1,
#   'License_Type': 'MIT License'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'machine-learning-signal-finder',
#   'Owner': 'elbernaderen',
#   'Description': 'Technic analyzer with ML (RTF)  and signal sender bot using  telegram',
#   'URL': 'https://github.com/elbernaderen/machine-learning-signal-finder',
#   'Programming_Language': 'Python',
#   'Creation_Date': '2022-02-15T00:39:58Z',
#   'Last_Updated_Date': '2024-08-16T09:50:09Z',
#   'Number_of_Stars': 15,
#   'Number_of_Forks': 10,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'MIT License'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'algorithmia',
#   'Owner': 'snlpatel001213',
#   'Description': None,
#   'URL': 'https://github.com/snlpatel001213/algorithmia',
#   'Programming_Language': 'Jupyter Notebook',
#   'Creation_Date': '2017-03-07T06:17:33Z',
#   'Last_Updated_Date': '2021-06-28T18:07:46Z',
#   'Number_of_Stars': 15,
#   'Number_of_Forks': 14,
#   'Number_of_Open_Issues': 105,
#   'License_Type': 'GNU General Public License v3.0'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'MalwareClassify',
#   'Owner': 'goodskillprogramer',
#   'Description': 'malware classify 第三届『阿里云安全算法挑战赛』源码',
#   'URL': 'https://github.com/goodskillprogramer/MalwareClassify',
#   'Programming_Language': 'Python',
#   'Creation_Date': '2018-09-29T07:41:40Z',
#   'Last_Updated_Date': '2023-08-17T07:15:43Z',
#   'Number_of_Stars': 15,
#   'Number_of_Forks': 2,
#   'Number_of_Open_Issues': 3,
#   'License_Type': 'Unknown'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'grandMatronPlugin',
#   'Owner': 'nicholasbulka',
#   'Description': 'This is an audio neural network plugin modeling a low pass filter. Built in JUCE.',
#   'URL': 'https://github.com/nicholasbulka/grandMatronPlugin',
#   'Programming_Language': 'C++',
#   'Creation_Date': '2023-03-24T22:12:07Z',
#   'Last_Updated_Date': '2024-02-15T12:37:31Z',
#   'Number_of_Stars': 15,
#   'Number_of_Forks': 0,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'Apache License 2.0'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'toygrad',
#   'Owner': 'fabiospampinato',
#   'Description': 'A toy library for building simple neural networks which can be serialized to compact JSON.',
#   'URL': 'https://github.com/fabiospampinato/toygrad',
#   'Programming_Language': 'TypeScript',
#   'Creation_Date': '2022-11-30T02:07:31Z',
#   'Last_Updated_Date': '2024-03-11T02:09:48Z',
#   'Number_of_Stars': 15,
#   'Number_of_Forks': 0,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'MIT License'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'AWS_Machine_Learning_Specialty_MLS-C01',
#   'Owner': 'simonguenther',
#   'Description': "My detailed experience of taking Amazon's Machine Learning Specialty exam",
#   'URL': 'https://github.com/simonguenther/AWS_Machine_Learning_Specialty_MLS-C01',
#   'Programming_Language': None,
#   'Creation_Date': '2020-08-04T06:05:14Z',
#   'Last_Updated_Date': '2024-03-01T14:24:46Z',
#   'Number_of_Stars': 15,
#   'Number_of_Forks': 1,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'Unknown'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'MultiAug',
#   'Owner': 'Devin-Taylor',
#   'Description': 'Multi-modal data augmentation for machine learning',
#   'URL': 'https://github.com/Devin-Taylor/MultiAug',
#   'Programming_Language': 'Python',
#   'Creation_Date': '2019-04-30T22:41:35Z',
#   'Last_Updated_Date': '2024-01-04T16:33:23Z',
#   'Number_of_Stars': 15,
#   'Number_of_Forks': 0,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'MIT License'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'Breast-cancer-prediction',
#   'Owner': '0xpranjal',
#   'Description': 'Breast cancer detection using 4 different models i.e. Logistic Regression, KNN, SVM, and Decision Tree Machine Learning models and optimizing them for even a better accuracy.',
#   'URL': 'https://github.com/0xpranjal/Breast-cancer-prediction',
#   'Programming_Language': 'Jupyter Notebook',
#   'Creation_Date': '2020-04-26T05:53:17Z',
#   'Last_Updated_Date': '2024-07-28T18:10:01Z',
#   'Number_of_Stars': 14,
#   'Number_of_Forks': 7,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'MIT License'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'gender-graph',
#   'Owner': 'Kif11',
#   'Description': 'Word graph web application that displays gender biases in Wikipedia, Reddit and Google News',
#   'URL': 'https://github.com/Kif11/gender-graph',
#   'Programming_Language': 'JavaScript',
#   'Creation_Date': '2017-05-15T20:35:16Z',
#   'Last_Updated_Date': '2022-03-04T17:15:14Z',
#   'Number_of_Stars': 14,
#   'Number_of_Forks': 1,
#   'Number_of_Open_Issues': 1,
#   'License_Type': 'Unknown'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'faceDetection',
#   'Owner': 'cimplesid',
#   'Description': 'facedetection flutter .mlkit',
#   'URL': 'https://github.com/cimplesid/faceDetection',
#   'Programming_Language': 'Dart',
#   'Creation_Date': '2019-07-04T08:21:04Z',
#   'Last_Updated_Date': '2024-09-22T10:55:52Z',
#   'Number_of_Stars': 13,
#   'Number_of_Forks': 10,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'Unknown'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'HebbianPCA',
#   'Owner': 'GabrieleLagani',
#   'Description': 'Pytorch implementation of Hebbian learning algorithms to train deep convolutional neural networks. ',
#   'URL': 'https://github.com/GabrieleLagani/HebbianPCA',
#   'Programming_Language': 'Python',
#   'Creation_Date': '2020-03-23T16:21:27Z',
#   'Last_Updated_Date': '2024-03-02T07:27:06Z',
#   'Number_of_Stars': 13,
#   'Number_of_Forks': 3,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'MIT License'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'autonomous_quadrotor_environment',
#   'Owner': 'rafaelcostafrf',
#   'Description': 'Autonomous Quadrotor 3D environment, based on python.',
#   'URL': 'https://github.com/rafaelcostafrf/autonomous_quadrotor_environment',
#   'Programming_Language': 'Python',
#   'Creation_Date': '2020-04-26T00:19:16Z',
#   'Last_Updated_Date': '2024-04-09T06:15:45Z',
#   'Number_of_Stars': 13,
#   'Number_of_Forks': 6,
#   'Number_of_Open_Issues': 2,
#   'License_Type': 'Creative Commons Zero v1.0 Universal'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'oxygenjs',
#   'Owner': 'saichandrareddy1',
#   'Description': 'This a JavaScript Library for the Numerical Javascript and Machine Learning',
#   'URL': 'https://github.com/saichandrareddy1/oxygenjs',
#   'Programming_Language': 'JavaScript',
#   'Creation_Date': '2020-08-04T12:18:25Z',
#   'Last_Updated_Date': '2021-02-01T05:45:27Z',
#   'Number_of_Stars': 13,
#   'Number_of_Forks': 0,
#   'Number_of_Open_Issues': 1,
#   'License_Type': 'MIT License'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'mlbook-titanic',
#   'Owner': 'r-hassan-zz',
#   'Description': 'মেশিন লার্নিং: প্রজেক্ট ওয়ার্কবুক টাইটানিক',
#   'URL': 'https://github.com/r-hassan-zz/mlbook-titanic',
#   'Programming_Language': None,
#   'Creation_Date': '2017-09-21T13:49:23Z',
#   'Last_Updated_Date': '2024-06-18T17:26:51Z',
#   'Number_of_Stars': 12,
#   'Number_of_Forks': 11,
#   'Number_of_Open_Issues': 1,
#   'License_Type': 'GNU General Public License v3.0'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'synthetico',
#   'Owner': 'marcovisibelli',
#   'Description': 'general-purpose synthetic data generators to enable data science experiments',
#   'URL': 'https://github.com/marcovisibelli/synthetico',
#   'Programming_Language': 'Python',
#   'Creation_Date': '2018-10-03T08:48:21Z',
#   'Last_Updated_Date': '2022-07-21T08:16:11Z',
#   'Number_of_Stars': 12,
#   'Number_of_Forks': 2,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'Unknown'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'SFCLS',
#   'Owner': 'johnjaniczek',
#   'Description': 'sparse and fully constrained spectral unmixing algorithm',
#   'URL': 'https://github.com/johnjaniczek/SFCLS',
#   'Programming_Language': 'Python',
#   'Creation_Date': '2019-05-01T00:55:44Z',
#   'Last_Updated_Date': '2023-05-14T15:32:37Z',
#   'Number_of_Stars': 12,
#   'Number_of_Forks': 1,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'Unknown'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'twin-check',
#   'Owner': 'lyubchev',
#   'Description': '📷 Web app that determines the similarity value between two faces using face-api.js and your camera!',
#   'URL': 'https://github.com/lyubchev/twin-check',
#   'Programming_Language': 'JavaScript',
#   'Creation_Date': '2018-08-16T13:46:17Z',
#   'Last_Updated_Date': '2024-07-14T11:45:26Z',
#   'Number_of_Stars': 12,
#   'Number_of_Forks': 1,
#   'Number_of_Open_Issues': 1,
#   'License_Type': 'MIT License'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'Machine-Learning-Software-that-predicts-planets-based-on-their-distance-from-the-sun-number-of-sate',
#   'Owner': 'emirhanai',
#   'Description': 'Machine Learning Software that predicts planets based on their distance from the sun, number of satellites and various properties',
#   'URL': 'https://github.com/emirhanai/Machine-Learning-Software-that-predicts-planets-based-on-their-distance-from-the-sun-number-of-sate',
#   'Programming_Language': 'Python',
#   'Creation_Date': '2021-08-29T12:40:27Z',
#   'Last_Updated_Date': '2024-06-04T18:46:43Z',
#   'Number_of_Stars': 12,
#   'Number_of_Forks': 0,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'MIT License'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'Tesla-Car-Range-Base-Price-and-Exact-Price-Prediction---Machine-Learning',
#   'Owner': 'emirhanai',
#   'Description': 'Tesla Car Range, Base Price and Precise Price Prediction - Machine Learning',
#   'URL': 'https://github.com/emirhanai/Tesla-Car-Range-Base-Price-and-Exact-Price-Prediction---Machine-Learning',
#   'Programming_Language': 'Python',
#   'Creation_Date': '2021-08-15T22:47:59Z',
#   'Last_Updated_Date': '2024-07-22T05:03:44Z',
#   'Number_of_Stars': 11,
#   'Number_of_Forks': 11,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'MIT License'},
#  {'Topic': 'machine learning',
#   'Repository_Name': 'LightGbmDotNet',
#   'Owner': 'fstandhartinger',
#   'Description': 'A .NET wrapper for the LightGBM machine learning library',
#   'URL': 'https://github.com/fstandhartinger/LightGbmDotNet',
#   'Programming_Language': 'C#',
# ...
#   'Number_of_Stars': 1,
#   'Number_of_Forks': 0,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'Unknown'},
#  {'Topic': 'big data',
#   'Repository_Name': 'kafka-Druid-Imply-Dashboard',
#   'Owner': 'gauravshelangia',
#   'Description': 'Task is to create a data pipeline that extracts this data from the API and populates a database that allows your company to view the following properties of an influencer over time. The dashboard  has been built using druid as time series db, kafka for stream.',
#   'URL': 'https://github.com/gauravshelangia/kafka-Druid-Imply-Dashboard',
#   'Programming_Language': 'TypeScript',
#   'Creation_Date': '2018-09-02T21:10:36Z',
#   'Last_Updated_Date': '2023-01-25T00:19:47Z',
#   'Number_of_Stars': 1,
#   'Number_of_Forks': 0,
#   'Number_of_Open_Issues': 4,
#   'License_Type': 'Unknown'},
#  {'Topic': 'big data',
#   'Repository_Name': 'CollocationsFinder',
#   'Owner': 'nikczemnydev',
#   'Description': 'Java - CollocationsFinder - in Computational Linguistics collocations are words that appear together much more often than they would only by chance.  This program can be trained on any text, then based on some factors it will tell you if any 2 words you want to search for are collocations.',
#   'URL': 'https://github.com/nikczemnydev/CollocationsFinder',
#   'Programming_Language': 'Java',
#   'Creation_Date': '2023-12-21T21:41:48Z',
#   'Last_Updated_Date': '2024-01-31T16:59:11Z',
#   'Number_of_Stars': 1,
#   'Number_of_Forks': 0,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'Unknown'},
#  {'Topic': 'big data',
#   'Repository_Name': 'Personality_Prediction_UsingML',
#   'Owner': 'nikhil-188',
#   'Description': 'Here I developed a machine learning model for predicting personality traits. It analyzes personal behavior data and uses algorithms like KNN, Logistic Regression, Decision Tree to classify individuals based on traits. It automates the personality assessment process, providing insights for social media, advertising, and recruitment.',
#   'URL': 'https://github.com/nikhil-188/Personality_Prediction_UsingML',
#   'Programming_Language': 'HTML',
#   'Creation_Date': '2023-07-03T11:10:43Z',
#   'Last_Updated_Date': '2024-04-07T04:37:09Z',
#   'Number_of_Stars': 1,
#   'Number_of_Forks': 1,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'Unknown'},
#  {'Topic': 'big data',
#   'Repository_Name': 'bigdata',
#   'Owner': 'rodesta2212',
#   'Description': 'repo untuk kuliah big data',
#   'URL': 'https://github.com/rodesta2212/bigdata',
#   'Programming_Language': 'Jupyter Notebook',
#   'Creation_Date': '2018-09-13T08:33:24Z',
#   'Last_Updated_Date': '2023-11-18T07:11:44Z',
#   'Number_of_Stars': 0,
#   'Number_of_Forks': 4,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'Unknown'},
#  {'Topic': 'big data',
#   'Repository_Name': 'json-java-processing',
#   'Owner': 'rashnil-git',
#   'Description': 'Pre-Processing for JSON Data into Hive format',
#   'URL': 'https://github.com/rashnil-git/json-java-processing',
#   'Programming_Language': 'Java',
#   'Creation_Date': '2016-10-16T22:17:16Z',
#   'Last_Updated_Date': '2023-02-24T02:47:23Z',
#   'Number_of_Stars': 0,
#   'Number_of_Forks': 0,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'Unknown'},
#  {'Topic': 'big data',
#   'Repository_Name': 'hadoop',
#   'Owner': 'bansal97',
#   'Description': None,
#   'URL': 'https://github.com/bansal97/hadoop',
#   'Programming_Language': None,
#   'Creation_Date': '2017-07-12T15:25:17Z',
#   'Last_Updated_Date': '2023-02-24T02:47:31Z',
#   'Number_of_Stars': 0,
#   'Number_of_Forks': 0,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'Unknown'},
#  {'Topic': 'big data',
#   'Repository_Name': 'Test',
#   'Owner': 'draemann',
#   'Description': 'This is a test account',
#   'URL': 'https://github.com/draemann/Test',
#   'Programming_Language': None,
#   'Creation_Date': '2017-04-15T13:23:19Z',
#   'Last_Updated_Date': '2023-02-24T02:47:28Z',
#   'Number_of_Stars': 0,
#   'Number_of_Forks': 0,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'Unknown'},
#  {'Topic': 'big data',
#   'Repository_Name': 'DataMerge',
#   'Owner': 'ryanvickr',
#   'Description': 'This program will scan a directory for multiple data files in columns (separated by the | symbol), and merge all of them. It currently can handle data files where columns are in different orders.',
#   'URL': 'https://github.com/ryanvickr/DataMerge',
#   'Programming_Language': 'Java',
#   'Creation_Date': '2018-03-27T00:38:49Z',
#   'Last_Updated_Date': '2024-02-11T07:18:50Z',
#   'Number_of_Stars': 0,
#   'Number_of_Forks': 0,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'Unknown'},
#  {'Topic': 'big data',
#   'Repository_Name': 'big-data-Hadoop',
#   'Owner': 'axnamit',
#   'Description': None,
#   'URL': 'https://github.com/axnamit/big-data-Hadoop',
#   'Programming_Language': None,
#   'Creation_Date': '2018-06-27T09:32:41Z',
#   'Last_Updated_Date': '2023-02-24T02:47:44Z',
#   'Number_of_Stars': 0,
#   'Number_of_Forks': 0,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'Unknown'},
#  {'Topic': 'big data',
#   'Repository_Name': 'Data-Wrangling-Using-Pyspark-for-Video-Games-Datasets',
#   'Owner': 'ajitmane36',
#   'Description': 'The objective was to complete data engineering task for IndiGG interview using pyspark. Includes dataset download, processing, analysis using Python, Spark, AWS Glue, Lambda, Step Functions, and SQL.',
#   'URL': 'https://github.com/ajitmane36/Data-Wrangling-Using-Pyspark-for-Video-Games-Datasets',
#   'Programming_Language': 'Jupyter Notebook',
#   'Creation_Date': '2023-06-24T16:19:34Z',
#   'Last_Updated_Date': '2024-07-09T14:15:33Z',
#   'Number_of_Stars': 0,
#   'Number_of_Forks': 1,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'Unknown'},
#  {'Topic': 'big data',
#   'Repository_Name': 'data-analytics',
#   'Owner': 'sanjifr3',
#   'Description': 'MIE1512H - Data Analytics - University of Toronto - Course Work',
#   'URL': 'https://github.com/sanjifr3/data-analytics',
#   'Programming_Language': 'HTML',
#   'Creation_Date': '2017-02-05T21:25:08Z',
#   'Last_Updated_Date': '2023-02-24T02:47:25Z',
#   'Number_of_Stars': 0,
#   'Number_of_Forks': 0,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'Unknown'},
#  {'Topic': 'big data',
#   'Repository_Name': 'Data_Engineering_Essentials',
#   'Owner': 'nadeemtaj407',
#   'Description': 'This repository will cover all important data engineering concepts, skills that will help you become a successful data engineer. You will learn the basics of data engineer, the important algorithms used by data engineer.',
#   'URL': 'https://github.com/nadeemtaj407/Data_Engineering_Essentials',
#   'Programming_Language': None,
#   'Creation_Date': '2023-03-19T18:20:45Z',
#   'Last_Updated_Date': '2023-03-19T18:26:38Z',
#   'Number_of_Stars': 0,
#   'Number_of_Forks': 0,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'Unknown'},
#  {'Topic': 'big data',
#   'Repository_Name': 'Big-Data-Codo-a-Codo-4.0-2023',
#   'Owner': 'aniascua',
#   'Description': 'Me encuentro realizando el curso de Big Data de Codo a Codo 4.0 brindado por el Gobierno de la Ciudad Autónoma de Buenos Aires. Tiene una duración de 4 meses. Enseña habilidades y herramientas para trabajar con grandes cantidades de datos y tomar decisiones informadas.',
#   'URL': 'https://github.com/aniascua/Big-Data-Codo-a-Codo-4.0-2023',
#   'Programming_Language': None,
#   'Creation_Date': '2023-04-07T02:21:04Z',
#   'Last_Updated_Date': '2023-05-12T20:34:04Z',
#   'Number_of_Stars': 0,
#   'Number_of_Forks': 1,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'Unknown'},
#  {'Topic': 'big data',
#   'Repository_Name': 'BigData',
#   'Owner': 'keymanky',
#   'Description': 'Repository with algorithms, examples, configurations of tools of big data and data science',
#   'URL': 'https://github.com/keymanky/BigData',
#   'Programming_Language': 'Python',
#   'Creation_Date': '2018-11-13T15:14:03Z',
#   'Last_Updated_Date': '2023-02-24T02:47:48Z',
#   'Number_of_Stars': 0,
#   'Number_of_Forks': 0,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'Unknown'},
#  {'Topic': 'big data',
#   'Repository_Name': 'big-data-ex',
#   'Owner': 'vic1507',
#   'Description': None,
#   'URL': 'https://github.com/vic1507/big-data-ex',
#   'Programming_Language': 'Java',
#   'Creation_Date': '2018-06-12T16:55:23Z',
#   'Last_Updated_Date': '2023-02-24T02:47:44Z',
#   'Number_of_Stars': 0,
#   'Number_of_Forks': 0,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'Unknown'},
#  {'Topic': 'big data',
#   'Repository_Name': 'Extreme-value-analysis-of-huge-datasets',
#   'Owner': 'OGCJN',
#   'Description': 'PhD Thesis. Some results in Extreme Value Theory with applications to High-Throughput Screening and Bioinformatics.',
#   'URL': 'https://github.com/OGCJN/Extreme-value-analysis-of-huge-datasets',
#   'Programming_Language': None,
#   'Creation_Date': '2017-12-10T20:54:14Z',
#   'Last_Updated_Date': '2023-02-24T02:47:38Z',
#   'Number_of_Stars': 0,
#   'Number_of_Forks': 0,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'Unknown'},
#  {'Topic': 'big data',
#   'Repository_Name': 'Distributed-Systems_project',
#   'Owner': 'ma-he-sh',
#   'Description': 'Distributed Systems group project',
#   'URL': 'https://github.com/ma-he-sh/Distributed-Systems_project',
#   'Programming_Language': 'CSS',
#   'Creation_Date': '2017-10-26T04:11:47Z',
#   'Last_Updated_Date': '2023-02-24T02:47:36Z',
#   'Number_of_Stars': 0,
#   'Number_of_Forks': 0,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'Unknown'},
#  {'Topic': 'big data',
#   'Repository_Name': 'CESI_BigData_LoLGameDownloadAndFormat',
#   'Owner': 'InFinity54',
#   'Description': "C# application created and used to convert JSON games data retrieved from Riot Games' API for League of Legends at CESI, for the Big Data lesson. Only available in French.",
#   'URL': 'https://github.com/InFinity54/CESI_BigData_LoLGameDownloadAndFormat',
#   'Programming_Language': 'C#',
#   'Creation_Date': '2021-05-28T14:27:45Z',
#   'Last_Updated_Date': '2023-02-24T02:48:13Z',
#   'Number_of_Stars': 0,
#   'Number_of_Forks': 0,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'Unknown'},
#  {'Topic': 'big data',
#   'Repository_Name': 'Data-engineer-end-to-end-project-airflow-dbt-soda-bigquery',
#   'Owner': 'niyotham',
#   'Description': 'An end to end data engineering project for loading data into bigquery with airflow, perform transformations using dbt and do  data quality check with soday',
#   'URL': 'https://github.com/niyotham/Data-engineer-end-to-end-project-airflow-dbt-soda-bigquery',
#   'Programming_Language': 'Python',
#   'Creation_Date': '2023-10-17T12:02:34Z',
#   'Last_Updated_Date': '2023-10-19T13:04:38Z',
#   'Number_of_Stars': 0,
#   'Number_of_Forks': 0,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'Unknown'},
#  {'Topic': 'big data',
#   'Repository_Name': 'Process-Mining',
#   'Owner': 'vicmertens',
#   'Description': 'Process Mining in R using the bupaR package',
#   'URL': 'https://github.com/vicmertens/Process-Mining',
#   'Programming_Language': 'HTML',
#   'Creation_Date': '2020-05-08T07:09:24Z',
#   'Last_Updated_Date': '2023-02-24T02:48:02Z',
#   'Number_of_Stars': 0,
#   'Number_of_Forks': 1,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'MIT License'},
#  {'Topic': 'big data',
#   'Repository_Name': 'coursera_analysis_with_spark_scala',
#   'Owner': 'Stardust1002',
#   'Description': 'Big Data Analysis assignments with Scala and Spark by École Polytechnique Fédérale de Lausanne',
#   'URL': 'https://github.com/Stardust1002/coursera_analysis_with_spark_scala',
#   'Programming_Language': 'XSLT',
#   'Creation_Date': '2017-03-17T14:19:16Z',
#   'Last_Updated_Date': '2023-02-24T02:47:27Z',
#   'Number_of_Stars': 0,
#   'Number_of_Forks': 0,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'Unknown'},
#  {'Topic': 'big data',
#   'Repository_Name': 'CLOUDERA',
#   'Owner': 'VaishnavJois',
#   'Description': 'Cloudera commands used for Big Data Analytics',
#   'URL': 'https://github.com/VaishnavJois/CLOUDERA',
#   'Programming_Language': None,
#   'Creation_Date': '2020-02-24T16:48:03Z',
#   'Last_Updated_Date': '2023-02-24T02:48:00Z',
#   'Number_of_Stars': 0,
#   'Number_of_Forks': 0,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'Unknown'},
#  {'Topic': 'big data',
#   'Repository_Name': 'frog2features',
#   'Owner': 'davidmacro',
#   'Description': 'R library to create high quality NLP-based features from FROG output',
#   'URL': 'https://github.com/davidmacro/frog2features',
#   'Programming_Language': 'R',
#   'Creation_Date': '2018-03-15T14:37:23Z',
#   'Last_Updated_Date': '2021-10-21T13:40:40Z',
#   'Number_of_Stars': 0,
#   'Number_of_Forks': 1,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'GNU General Public License v3.0'},
#  {'Topic': 'big data',
#   'Repository_Name': 'bootpenal',
#   'Owner': 'guhjy',
#   'Description': 'R package: Bootstrap Penalization for variable selection with big data',
#   'URL': 'https://github.com/guhjy/bootpenal',
#   'Programming_Language': None,
#   'Creation_Date': '2016-12-14T07:46:31Z',
#   'Last_Updated_Date': '2018-02-25T05:47:44Z',
#   'Number_of_Stars': 0,
#   'Number_of_Forks': 0,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'Other'},
#  {'Topic': 'big data',
#   'Repository_Name': 'Projects',
#   'Owner': 'Giannix1993',
#   'Description': None,
#   'URL': 'https://github.com/Giannix1993/Projects',
#   'Programming_Language': None,
#   'Creation_Date': '2017-06-27T08:38:39Z',
#   'Last_Updated_Date': '2017-06-27T08:40:35Z',
#   'Number_of_Stars': 0,
#   'Number_of_Forks': 0,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'Unknown'},
#  {'Topic': 'big data',
#   'Repository_Name': 'FacebookGlobalCities',
#   'Owner': 'riquedev',
#   'Description': 'Obtenha ID, Nome, Latitude, Longitude de determinado local a partir do próprio Facebook.',
#   'URL': 'https://github.com/riquedev/FacebookGlobalCities',
#   'Programming_Language': 'PHP',
#   'Creation_Date': '2017-08-12T11:42:47Z',
#   'Last_Updated_Date': '2017-08-12T12:50:13Z',
#   'Number_of_Stars': 0,
#   'Number_of_Forks': 0,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'MIT License'},
#  {'Topic': 'big data',
#   'Repository_Name': 'NOAA_GHCND',
#   'Owner': 'glider4',
#   'Description': 'Conversion and ingestion of NOAA GHCN-D weather data into PostgreSQL database and querying.  Python, R, SQL, Scala',
#   'URL': 'https://github.com/glider4/NOAA_GHCND',
#   'Programming_Language': 'Python',
#   'Creation_Date': '2020-02-15T03:44:41Z',
#   'Last_Updated_Date': '2021-02-01T02:07:24Z',
#   'Number_of_Stars': 0,
#   'Number_of_Forks': 1,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'GNU General Public License v3.0'},
#  {'Topic': 'big data',
#   'Repository_Name': 'DSA_leetcode',
#   'Owner': 'tinyHiker',
#   'Description': 'This directory hold  my work on data structures and algorithms. It also holds some of my leetcode practice.',
#   'URL': 'https://github.com/tinyHiker/DSA_leetcode',
#   'Programming_Language': 'Python',
#   'Creation_Date': '2024-01-24T23:21:25Z',
#   'Last_Updated_Date': '2024-01-25T00:42:23Z',
#   'Number_of_Stars': 0,
#   'Number_of_Forks': 0,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'Unknown'},
#  {'Topic': 'big data',
#   'Repository_Name': 'Search-engine---English-Wikipedia',
#   'Owner': 'noama11',
#   'Description': "Search engine for Wikipedia's 6.3M+ documents. Involves data preprocessing, inverted indexes, and metrics like Precision@5. Includes a Flask frontend for query processing.",
#   'URL': 'https://github.com/noama11/Search-engine---English-Wikipedia',
#   'Programming_Language': 'Python',
#   'Creation_Date': '2024-02-23T09:05:18Z',
#   'Last_Updated_Date': '2024-08-17T17:08:29Z',
#   'Number_of_Stars': 0,
#   'Number_of_Forks': 0,
#   'Number_of_Open_Issues': 0,
#   'License_Type': 'Unknown'},
#  {'Topic': 'big data',
#   'Repository_Name': 'dc-ai-ml-lab',
#   'Owner': 'karasatishkumar',
#   'Description': 'This repository is to demonstrate some of the concept of distributed computing and machine learning using apache spark. It will be having different projects to solve different data use cases/ problems. Each use case will have different set of tools along with apache spark.',
#   'URL': 'https://github.com/karasatishkumar/dc-ai-ml-lab',
#   'Programming_Language': 'Java',
#   'Creation_Date': '2019-09-15T06:44:15Z',
#   'Last_Updated_Date': '2019-10-30T03:50:50Z',
#   'Number_of_Stars': 0,
#   'Number_of_Forks': 0,
#   'Number_of_Open_Issues': 1,
#   'License_Type': 'Unknown'}]

# %%
repo_df = pd.DataFrame(repository_data)
repo_df
# Out:
#                 Topic                    Repository_Name            Owner  \
# 0    machine learning         mit-deep-learning-book-pdf         janishar
# 1    machine learning           machine-learning-mindmap         dformoso
# 2    machine learning             rapping-neural-network     robbiebarrat
# 3    machine learning           awesome-machine-learning       onmyway133
# 4    machine learning                              DeepJ        calclavia
# ..                ...                                ...              ...
# 876          big data               FacebookGlobalCities         riquedev
# 877          big data                         NOAA_GHCND          glider4
# 878          big data                       DSA_leetcode        tinyHiker
# 879          big data  Search-engine---English-Wikipedia          noama11
# 880          big data                       dc-ai-ml-lab  karasatishkumar
#
#                                            Description  \
# 0    MIT Deep Learning Book in PDF format (complete...
# 1    A mindmap summarising Machine Learning concept...
# 2    Rap song writing recurrent neural network trai...
# 3    🎰 A curated list of machine learning resources...
# 4    A deep learning model for style-specific music...
# ..                                                 ...
# 876  Obtenha ID, Nome, Latitude, Longitude de deter...
# 877  Conversion and ingestion of NOAA GHCN-D weathe...
# 878  This directory hold  my work on data structure...
# 879  Search engine for Wikipedia's 6.3M+ documents....
# 880  This repository is to demonstrate some of the ...
#
#                                                    URL Programming_Language  \
# 0    https://github.com/janishar/mit-deep-learning-...                 Java
# 1    https://github.com/dformoso/machine-learning-m...                 None
# 2    https://github.com/robbiebarrat/rapping-neural...               Python
# 3    https://github.com/onmyway133/awesome-machine-...                 None
# 4                   https://github.com/calclavia/DeepJ               Python
# ..                                                 ...                  ...
# 876   https://github.com/riquedev/FacebookGlobalCities                  PHP
# 877              https://github.com/glider4/NOAA_GHCND               Python
# 878          https://github.com/tinyHiker/DSA_leetcode               Python
# 879  https://github.com/noama11/Search-engine---Eng...               Python
# 880    https://github.com/karasatishkumar/dc-ai-ml-lab                 Java
#
#             Creation_Date     Last_Updated_Date  Number_of_Stars  \
# 0    2017-04-07T10:46:50Z  2024-10-06T04:30:47Z            12783
# 1    2017-08-10T04:29:24Z  2024-10-05T15:14:52Z             6114
# 2    2016-11-03T22:39:49Z  2024-10-02T09:01:24Z             1043
# 3    2017-06-10T16:05:45Z  2024-10-02T04:41:22Z              807
# 4    2017-01-15T06:43:17Z  2024-09-25T05:00:44Z              725
# ..                    ...                   ...              ...
# 876  2017-08-12T11:42:47Z  2017-08-12T12:50:13Z                0
# 877  2020-02-15T03:44:41Z  2021-02-01T02:07:24Z                0
# 878  2024-01-24T23:21:25Z  2024-01-25T00:42:23Z                0
# 879  2024-02-23T09:05:18Z  2024-08-17T17:08:29Z                0
# 880  2019-09-15T06:44:15Z  2019-10-30T03:50:50Z                0
#
#      Number_of_Forks  Number_of_Open_Issues                     License_Type
# 0               2699                     12                          Unknown
# 1               1005                      4               Apache License 2.0
# 2                167                     14                          Unknown
# 3                106                      2                      MIT License
# 4                110                     16                      MIT License
# ..               ...                    ...                              ...
# 876                0                      0                      MIT License
# 877                1                      0  GNU General Public License v3.0
# 878                0                      0                          Unknown
# 879                0                      0                          Unknown
# 880                0                      1                          Unknown
#
# [881 rows x 12 columns]

# %%
# Function to fetch repository data
def fetch_repository_data(topic):
    params = {
        "q": f"topic:{topic}",
        "sort": "stars",
        "per_page": 100
    }

    response = requests.get(api_url, params=params)
    data = response.json()["items"]

    repository_data = []
    for item in data:
        repository_data.append({
            "Topic":topic,
            "Repository_Name": item["name"],
            "Owner": item["owner"]["login"],
            "Description": item["description"],
            "URL": item["html_url"],
            "Programming_Language": item["language"],
            "Creation_Date": item["created_at"],
            "Last_Updated_Date": item["updated_at"],
            "Number_of_Stars": item["stargazers_count"],
            "Number_of_Forks": item["forks_count"],
            "Number_of_Open_Issues": item["open_issues_count"],
            "License_Type": item["license"]["name"] if item["license"] else "Unknown"
        })

    return repository_data

repository_data = []
for topic in trending_topics:
    data = fetch_repository_data(topic)
    repository_data.extend(data)


repo_df = pd.DataFrame(repository_data)

# %%
repo_df
# Out:
#                 Topic                    Repository_Name            Owner  \
# 0    machine learning         mit-deep-learning-book-pdf         janishar
# 1    machine learning           machine-learning-mindmap         dformoso
# 2    machine learning             rapping-neural-network     robbiebarrat
# 3    machine learning           awesome-machine-learning       onmyway133
# 4    machine learning                              DeepJ        calclavia
# ..                ...                                ...              ...
# 876          big data               FacebookGlobalCities         riquedev
# 877          big data                         NOAA_GHCND          glider4
# 878          big data                       DSA_leetcode        tinyHiker
# 879          big data  Search-engine---English-Wikipedia          noama11
# 880          big data                       dc-ai-ml-lab  karasatishkumar
#
#                                            Description  \
# 0    MIT Deep Learning Book in PDF format (complete...
# 1    A mindmap summarising Machine Learning concept...
# 2    Rap song writing recurrent neural network trai...
# 3    🎰 A curated list of machine learning resources...
# 4    A deep learning model for style-specific music...
# ..                                                 ...
# 876  Obtenha ID, Nome, Latitude, Longitude de deter...
# 877  Conversion and ingestion of NOAA GHCN-D weathe...
# 878  This directory hold  my work on data structure...
# 879  Search engine for Wikipedia's 6.3M+ documents....
# 880  This repository is to demonstrate some of the ...
#
#                                                    URL Programming_Language  \
# 0    https://github.com/janishar/mit-deep-learning-...                 Java
# 1    https://github.com/dformoso/machine-learning-m...                 None
# 2    https://github.com/robbiebarrat/rapping-neural...               Python
# 3    https://github.com/onmyway133/awesome-machine-...                 None
# 4                   https://github.com/calclavia/DeepJ               Python
# ..                                                 ...                  ...
# 876   https://github.com/riquedev/FacebookGlobalCities                  PHP
# 877              https://github.com/glider4/NOAA_GHCND               Python
# 878          https://github.com/tinyHiker/DSA_leetcode               Python
# 879  https://github.com/noama11/Search-engine---Eng...               Python
# 880    https://github.com/karasatishkumar/dc-ai-ml-lab                 Java
#
#             Creation_Date     Last_Updated_Date  Number_of_Stars  \
# 0    2017-04-07T10:46:50Z  2024-10-06T04:30:47Z            12783
# 1    2017-08-10T04:29:24Z  2024-10-05T15:14:52Z             6114
# 2    2016-11-03T22:39:49Z  2024-10-02T09:01:24Z             1043
# 3    2017-06-10T16:05:45Z  2024-10-02T04:41:22Z              807
# 4    2017-01-15T06:43:17Z  2024-09-25T05:00:44Z              725
# ..                    ...                   ...              ...
# 876  2017-08-12T11:42:47Z  2017-08-12T12:50:13Z                0
# 877  2020-02-15T03:44:41Z  2021-02-01T02:07:24Z                0
# 878  2024-01-24T23:21:25Z  2024-01-25T00:42:23Z                0
# 879  2024-02-23T09:05:18Z  2024-08-17T17:08:29Z                0
# 880  2019-09-15T06:44:15Z  2019-10-30T03:50:50Z                0
#
#      Number_of_Forks  Number_of_Open_Issues                     License_Type
# 0               2699                     12                          Unknown
# 1               1005                      4               Apache License 2.0
# 2                167                     14                          Unknown
# 3                106                      2                      MIT License
# 4                110                     16                      MIT License
# ..               ...                    ...                              ...
# 876                0                      0                      MIT License
# 877                1                      0  GNU General Public License v3.0
# 878                0                      0                          Unknown
# 879                0                      0                          Unknown
# 880                0                      1                          Unknown
#
# [881 rows x 12 columns]

# %%
repo_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 881 entries, 0 to 880
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Topic                  881 non-null    object
#  1   Repository_Name        881 non-null    object
#  2   Owner                  881 non-null    object
#  3   Description            866 non-null    object
#  4   URL                    881 non-null    object
#  5   Programming_Language   783 non-null    object
#  6   Creation_Date          881 non-null    object
#  7   Last_Updated_Date      881 non-null    object
#  8   Number_of_Stars        881 non-null    int64
#  9   Number_of_Forks        881 non-null    int64
#  10  Number_of_Open_Issues  881 non-null    int64
#  11  License_Type           881 non-null    object
# dtypes: int64(3), object(9)
# memory usage: 82.7+ KB

# %%
# Find rows where 'Description' column has NaN values
null_rows = repo_df[repo_df['Description'].isnull()]

# Display the rows with null values in the 'Description' column
print(null_rows)
# Out:
#                            Topic  \
# 58              machine learning
# 77              machine learning
# 143           data visualization
# 186           data visualization
# 267                deep learning
# 280                deep learning
# 294                deep learning
# 296                deep learning
# 322  natural language processing
# 328  natural language processing
# 420             data engineering
# 856                     big data
# 859                     big data
# 865                     big data
# 875                     big data
#
#                                   Repository_Name             Owner  \
# 58                          Credit-Risk-Modelling        RegaipKURT
# 77                                    algorithmia    snlpatel001213
# 143                                    HistoryMap         Vis4Sense
# 186                      Python-for-data-analysis       buomsoo-kim
# 267                           DeepAndCrossNetwork           barkain
# 280  Machine-Learning-Engineer-Nanodegree-Udacity             DoDuy
# 294                           SemEval_2019_public      paulafortuna
# 296                                   person-reid       virajmavani
# 322                         Part-of-Speech-Tagger      nooristanima
# 328                           nlpandtextanalytics         swetharam
# 420  Sales-forecast-analysis-for-a-retail-company  NandithaSirigiri
# 856                                        hadoop          bansal97
# 859                               big-data-Hadoop           axnamit
# 865                                   big-data-ex           vic1507
# 875                                      Projects       Giannix1993
#
#     Description                                                URL  \
# 58         None  https://github.com/RegaipKURT/Credit-Risk-Mode...
# 77         None      https://github.com/snlpatel001213/algorithmia
# 143        None            https://github.com/Vis4Sense/HistoryMap
# 186        None  https://github.com/buomsoo-kim/Python-for-data...
# 267        None     https://github.com/barkain/DeepAndCrossNetwork
# 280        None  https://github.com/DoDuy/Machine-Learning-Engi...
# 294        None  https://github.com/paulafortuna/SemEval_2019_p...
# 296        None         https://github.com/virajmavani/person-reid
# 322        None  https://github.com/nooristanima/Part-of-Speech...
# 328        None   https://github.com/swetharam/nlpandtextanalytics
# 420        None  https://github.com/NandithaSirigiri/Sales-fore...
# 856        None                 https://github.com/bansal97/hadoop
# 859        None         https://github.com/axnamit/big-data-Hadoop
# 865        None             https://github.com/vic1507/big-data-ex
# 875        None            https://github.com/Giannix1993/Projects
#
#     Programming_Language         Creation_Date     Last_Updated_Date  \
# 58      Jupyter Notebook  2020-07-07T22:55:10Z  2024-09-24T05:34:44Z
# 77      Jupyter Notebook  2017-03-07T06:17:33Z  2021-06-28T18:07:46Z
# 143           JavaScript  2016-01-18T10:03:21Z  2024-10-05T20:30:13Z
# 186     Jupyter Notebook  2017-12-07T08:15:12Z  2024-01-07T14:42:54Z
# 267     Jupyter Notebook  2018-06-28T20:09:36Z  2023-05-12T08:06:28Z
# 280                 None  2018-02-28T16:24:35Z  2020-03-19T12:02:48Z
# 294               Python  2019-01-29T10:02:37Z  2023-07-24T15:05:47Z
# 296               Python  2018-05-15T09:54:07Z  2023-06-09T18:29:50Z
# 322                 Perl  2018-03-22T16:10:22Z  2023-02-24T02:47:41Z
# 328               Python  2018-05-01T03:16:13Z  2023-02-24T02:47:43Z
# 420               Python  2018-06-06T08:49:52Z  2023-04-15T08:48:06Z
# 856                 None  2017-07-12T15:25:17Z  2023-02-24T02:47:31Z
# 859                 None  2018-06-27T09:32:41Z  2023-02-24T02:47:44Z
# 865                 Java  2018-06-12T16:55:23Z  2023-02-24T02:47:44Z
# 875                 None  2017-06-27T08:38:39Z  2017-06-27T08:40:35Z
#
#      Number_of_Stars  Number_of_Forks  Number_of_Open_Issues  \
# 58                22                8                      0
# 77                15               14                    105
# 143               57                7                     29
# 186               17               16                      0
# 267                8                4                      0
# 280                5                3                      0
# 294                4                1                      0
# 296                4                0                      0
# 322                0                0                      0
# 328                0                0                      0
# 420                2                0                      0
# 856                0                0                      0
# 859                0                0                      0
# 865                0                0                      0
# 875                0                0                      0
#
#                         License_Type
# 58                           Unknown
# 77   GNU General Public License v3.0
# 143                          Unknown
# 186                          Unknown
# 267                          Unknown
# 280                          Unknown
# 294                      MIT License
# 296                          Unknown
# 322                          Unknown
# 328                          Unknown
# 420                          Unknown
# 856                          Unknown
# 859                          Unknown
# 865                          Unknown
# 875                          Unknown

# %%
# Count the number of null rows in the 'Description' column
null_count = repo_df['Description'].isnull().sum()
null_count
# Out:
# 15

# %% [markdown]
# # Data Cleaning:

# %%
# 1. Fill Missing Values
# 'Programming Language' might have missing values, fill with 'Unknown'
repo_df['Programming_Language'].fillna('Unknown', inplace=True)

# 'License Type' might be missing if no license is provided, fill with 'None'
repo_df['License_Type'].fillna('None', inplace=True)

# 'Description' might be missing if no Description is provided, fill with 'None'
repo_df['Description'].fillna('None', inplace=True)

# 2. Convert Dates to datetime format
repo_df['Creation_Date'] = pd.to_datetime(repo_df['Creation_Date']).dt.date
repo_df['Last_Updated_Date'] = pd.to_datetime(repo_df['Last_Updated_Date']).dt.date

# 3. Handle Duplicates (if any)
# Ensure that repositories are unique based on the repository name and owner
repo_df.drop_duplicates(subset=['Repository_Name', 'Owner'], inplace=True)

# 4. Ensure Data Consistency (Standardizing formats)
# Convert all text fields to lowercase for consistency
repo_df['Repository_Name'] = repo_df['Repository_Name'].str.lower()
repo_df['Owner'] = repo_df['Owner'].str.lower()
repo_df['Programming_Language'] = repo_df['Programming_Language'].str.lower()
repo_df['License_Type'] = repo_df['License_Type'].str.lower()

# 5. Change index name to 'ID' and start from 1
repo_df.index = repo_df.index + 1 
repo_df.index.name = 'ID'  


repo_df
# Out:
# C:\Users\ajay2\AppData\Local\Temp\ipykernel_54000\4107462495.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   repo_df['Programming_Language'].fillna('Unknown', inplace=True)
# C:\Users\ajay2\AppData\Local\Temp\ipykernel_54000\4107462495.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   repo_df['License_Type'].fillna('None', inplace=True)
# C:\Users\ajay2\AppData\Local\Temp\ipykernel_54000\4107462495.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   repo_df['Description'].fillna('None', inplace=True)
#                 Topic                    Repository_Name            Owner  \
# ID
# 1    machine learning         mit-deep-learning-book-pdf         janishar
# 2    machine learning           machine-learning-mindmap         dformoso
# 3    machine learning             rapping-neural-network     robbiebarrat
# 4    machine learning           awesome-machine-learning       onmyway133
# 5    machine learning                              deepj        calclavia
# ..                ...                                ...              ...
# 877          big data               facebookglobalcities         riquedev
# 878          big data                         noaa_ghcnd          glider4
# 879          big data                       dsa_leetcode        tinyhiker
# 880          big data  search-engine---english-wikipedia          noama11
# 881          big data                       dc-ai-ml-lab  karasatishkumar
#
#                                            Description  \
# ID
# 1    MIT Deep Learning Book in PDF format (complete...
# 2    A mindmap summarising Machine Learning concept...
# 3    Rap song writing recurrent neural network trai...
# 4    🎰 A curated list of machine learning resources...
# 5    A deep learning model for style-specific music...
# ..                                                 ...
# 877  Obtenha ID, Nome, Latitude, Longitude de deter...
# 878  Conversion and ingestion of NOAA GHCN-D weathe...
# 879  This directory hold  my work on data structure...
# 880  Search engine for Wikipedia's 6.3M+ documents....
# 881  This repository is to demonstrate some of the ...
#
#                                                    URL Programming_Language  \
# ID
# 1    https://github.com/janishar/mit-deep-learning-...                 java
# 2    https://github.com/dformoso/machine-learning-m...              unknown
# 3    https://github.com/robbiebarrat/rapping-neural...               python
# 4    https://github.com/onmyway133/awesome-machine-...              unknown
# 5                   https://github.com/calclavia/DeepJ               python
# ..                                                 ...                  ...
# 877   https://github.com/riquedev/FacebookGlobalCities                  php
# 878              https://github.com/glider4/NOAA_GHCND               python
# 879          https://github.com/tinyHiker/DSA_leetcode               python
# 880  https://github.com/noama11/Search-engine---Eng...               python
# 881    https://github.com/karasatishkumar/dc-ai-ml-lab                 java
#
#     Creation_Date Last_Updated_Date  Number_of_Stars  Number_of_Forks  \
# ID
# 1      2017-04-07        2024-10-06            12783             2699
# 2      2017-08-10        2024-10-05             6114             1005
# 3      2016-11-03        2024-10-02             1043              167
# 4      2017-06-10        2024-10-02              807              106
# 5      2017-01-15        2024-09-25              725              110
# ..            ...               ...              ...              ...
# 877    2017-08-12        2017-08-12                0                0
# 878    2020-02-15        2021-02-01                0                1
# 879    2024-01-24        2024-01-25                0                0
# 880    2024-02-23        2024-08-17                0                0
# 881    2019-09-15        2019-10-30                0                0
#
#      Number_of_Open_Issues                     License_Type
# ID
# 1                       12                          unknown
# 2                        4               apache license 2.0
# 3                       14                          unknown
# 4                        2                      mit license
# 5                       16                      mit license
# ..                     ...                              ...
# 877                      0                      mit license
# 878                      0  gnu general public license v3.0
# 879                      0                          unknown
# 880                      0                          unknown
# 881                      1                          unknown
#
# [857 rows x 12 columns]

# %%
repo_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 857 entries, 1 to 881
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Topic                  857 non-null    object
#  1   Repository_Name        857 non-null    object
#  2   Owner                  857 non-null    object
#  3   Description            857 non-null    object
#  4   URL                    857 non-null    object
#  5   Programming_Language   857 non-null    object
#  6   Creation_Date          857 non-null    object
#  7   Last_Updated_Date      857 non-null    object
#  8   Number_of_Stars        857 non-null    int64
#  9   Number_of_Forks        857 non-null    int64
#  10  Number_of_Open_Issues  857 non-null    int64
#  11  License_Type           857 non-null    object
# dtypes: int64(3), object(9)
# memory usage: 87.0+ KB

# %% [markdown]
# # Data Storage

# %%
from sqlalchemy import create_engine

# %%
# Replace with your PostgreSQL database connection details
# Format: 'postgresql+psycopg2://username:password@host:port/db_name'
username='postgres'
password='Ajay'

engine = create_engine('postgresql+psycopg2://postgres:Ajay@localhost:5432/github_data')
#con=engine.connect


# Save the DataFrame to the PostgreSQL database, overwrites the table if it exists
repo_df.to_sql('repositories', con=engine, if_exists='replace', index=False)
# Out:
# 857

# %% [markdown]
# # Data Retrival

# %%
engine = create_engine('postgresql+psycopg2://postgres:Ajay@localhost:5432/github_data')

# Load data from the PostgreSQL database
def load_data():
    query = "SELECT * FROM public.repositories;"
    df = pd.read_sql(query, engine)
    return df

# %%
data=load_data()
data
# Out:
#                 Topic                    Repository_Name            Owner  \
# 0    machine learning         mit-deep-learning-book-pdf         janishar
# 1    machine learning           machine-learning-mindmap         dformoso
# 2    machine learning             rapping-neural-network     robbiebarrat
# 3    machine learning           awesome-machine-learning       onmyway133
# 4    machine learning                              deepj        calclavia
# ..                ...                                ...              ...
# 852          big data               facebookglobalcities         riquedev
# 853          big data                         noaa_ghcnd          glider4
# 854          big data                       dsa_leetcode        tinyhiker
# 855          big data  search-engine---english-wikipedia          noama11
# 856          big data                       dc-ai-ml-lab  karasatishkumar
#
#                                            Description  \
# 0    MIT Deep Learning Book in PDF format (complete...
# 1    A mindmap summarising Machine Learning concept...
# 2    Rap song writing recurrent neural network trai...
# 3    🎰 A curated list of machine learning resources...
# 4    A deep learning model for style-specific music...
# ..                                                 ...
# 852  Obtenha ID, Nome, Latitude, Longitude de deter...
# 853  Conversion and ingestion of NOAA GHCN-D weathe...
# 854  This directory hold  my work on data structure...
# 855  Search engine for Wikipedia's 6.3M+ documents....
# 856  This repository is to demonstrate some of the ...
#
#                                                    URL Programming_Language  \
# 0    https://github.com/janishar/mit-deep-learning-...                 java
# 1    https://github.com/dformoso/machine-learning-m...              unknown
# 2    https://github.com/robbiebarrat/rapping-neural...               python
# 3    https://github.com/onmyway133/awesome-machine-...              unknown
# 4                   https://github.com/calclavia/DeepJ               python
# ..                                                 ...                  ...
# 852   https://github.com/riquedev/FacebookGlobalCities                  php
# 853              https://github.com/glider4/NOAA_GHCND               python
# 854          https://github.com/tinyHiker/DSA_leetcode               python
# 855  https://github.com/noama11/Search-engine---Eng...               python
# 856    https://github.com/karasatishkumar/dc-ai-ml-lab                 java
#
#     Creation_Date Last_Updated_Date  Number_of_Stars  Number_of_Forks  \
# 0      2017-04-07        2024-10-06            12783             2699
# 1      2017-08-10        2024-10-05             6114             1005
# 2      2016-11-03        2024-10-02             1043              167
# 3      2017-06-10        2024-10-02              807              106
# 4      2017-01-15        2024-09-25              725              110
# ..            ...               ...              ...              ...
# 852    2017-08-12        2017-08-12                0                0
# 853    2020-02-15        2021-02-01                0                1
# 854    2024-01-24        2024-01-25                0                0
# 855    2024-02-23        2024-08-17                0                0
# 856    2019-09-15        2019-10-30                0                0
#
#      Number_of_Open_Issues                     License_Type
# 0                       12                          unknown
# 1                        4               apache license 2.0
# 2                       14                          unknown
# 3                        2                      mit license
# 4                       16                      mit license
# ..                     ...                              ...
# 852                      0                      mit license
# 853                      0  gnu general public license v3.0
# 854                      0                          unknown
# 855                      0                          unknown
# 856                      1                          unknown
#
# [857 rows x 12 columns]

# %%
pip freeze > requirments.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -ip (c:\users\ajay2\appdata\local\programs\python\python310\lib\site-packages)
